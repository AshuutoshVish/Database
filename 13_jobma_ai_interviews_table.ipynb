# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
#candidate interview response data
jobma_ai_interviews_df = pd.read_sql("SELECT * FROM jobma_ai_interviews", engine)

# %%
jobma_ai_interviews_df.shape
# Out:
# (74, 17)

# %%
jobma_ai_interviews_df.T
# Out:
#                                                                      0   \
# id                                                                    1
# jobma_post_id                                                     33421
# jobma_pitcher_id                                                1124457
# jobma_catcher_id                                                   1873
# interview_applied_id                                              64807
# jobma_invitation_id                                              574457
# jobma_answers         {"answer": {"feedback": {"overall": {"score": ...
# payment_status                                                        1
# interview_rate                                                      0.0
# interview_credit                                                    NaN
# view_date                                                           NaT
# subscription_type                                                     0
# ...

# %%
# ai_interviews_df=jobma_ai_interviews_df[['id',
#                                         # 'jobma_post_id',#@8 
#                                         # 'jobma_pitcher_id', #@66 #33421--49, 34089--13, 
#                                         'jobma_catcher_id',#@3,  64827-3, 64811-2....

#                                         # 'interview_applied_id',#@68, 64827--3, 648112 
#                                         'jobma_invitation_id',#@73 575621-2, 574473--1
#                                         # 'jobma_answers', #@72 Video answers, evaluations dictionary

#                                         # 'payment_status', #@2 1,0
#                                         'interview_rate',#@3,  1.0, 0.0, 2.0...............>>??
#                                         'interview_credit',#@2   1.0, Nan, 2.0
#                                         # 'view_date',#date when does it view or evaluated

#                                         'subscription_type',#@1  0 in all
#                                         'interview_cost_type',#@1  0 in all
#                                         'cron_status',#@3   1,2,0-->1,2
#                                         # 'deleted_at',

#                                         # 'created_at',
#                                         # 'updated_at'
#                                        ]]

# %%
ai_interviews_df = jobma_ai_interviews_df[['id',
                                           'jobma_catcher_id',#@3,  64827-3, 64811-2....
                                           'interview_rate',#@3,  1.0, 0.0, 2.0...............>>??
                                           'interview_credit',#@2   1.0, Nan, 2.0
                                          ]]

# %%
jobma_ai_interviews_df.shape, ai_interviews_df.shape
# Out:
# ((74, 17), (74, 4))

# %%
ai_interviews_df
# Out:
#      id  jobma_catcher_id  interview_rate  interview_credit
# 0     1              1873             0.0               NaN
# 1     3              1873             0.0               NaN
# 2     5              1873             0.0               NaN
# 3     7              1873             0.0               NaN
# 4     9              1873             0.0               NaN
# ..  ...               ...             ...               ...
# 69  141              1873             1.0               1.0
# 70  143              1873             1.0               1.0
# 71  145              1873             2.0               2.0
# 72  147              1873             2.0               2.0
# 73  149              1873             2.0               2.0
#
# [74 rows x 4 columns]

# %%
ai_interviews_df.nunique()
# Out:
# id                  74
# jobma_catcher_id     3
# interview_rate       3
# interview_credit     2
# dtype: int64

# %%
ai_interviews_df.rename(columns={'jobma_catcher_id': 'catcher_id'}, inplace=True)
# Out:
# C:\Users\SSI\AppData\Local\Temp\ipykernel_9556\1785853826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ai_interviews_df.rename(columns={'jobma_catcher_id': 'catcher_id'}, inplace=True)

# %%
ai_interviews_df['ai_interview_counts'] = ai_interviews_df['catcher_id'].map(ai_interviews_df['catcher_id'].value_counts())
# Out:
# C:\Users\SSI\AppData\Local\Temp\ipykernel_9556\2551229909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ai_interviews_df['ai_interview_counts'] = ai_interviews_df['catcher_id'].map(ai_interviews_df['catcher_id'].value_counts())

# %%
ai_interviews_df
# Out:
#      id  catcher_id  interview_rate  interview_credit  ai_interview_counts
# 0     1        1873             0.0               NaN                   67
# 1     3        1873             0.0               NaN                   67
# 2     5        1873             0.0               NaN                   67
# 3     7        1873             0.0               NaN                   67
# 4     9        1873             0.0               NaN                   67
# ..  ...         ...             ...               ...                  ...
# 69  141        1873             1.0               1.0                   67
# 70  143        1873             1.0               1.0                   67
# 71  145        1873             2.0               2.0                   67
# 72  147        1873             2.0               2.0                   67
# 73  149        1873             2.0               2.0                   67
#
# [74 rows x 5 columns]

# %%
ai_interviews_df=ai_interviews_df[['catcher_id', 'ai_interview_counts']]

# %%
ai_interviews_df.shape
# Out:
# (74, 2)

# %%
ai_interviews_df.duplicated().sum()
# Out:
# np.int64(71)

# %%
ai_interviews_df.drop_duplicates(inplace=True)
# Out:
# C:\Users\SSI\AppData\Local\Temp\ipykernel_9556\2413312109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ai_interviews_df.drop_duplicates(inplace=True)

# %%
ai_interviews_df
# Out:
#     catcher_id  ai_interview_counts
# 0         1873                   67
# 15        8597                    5
# 63        9299                    2

# %%
ai_interviews_df.to_csv("ai_interviews_df.csv", index=False)
