# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
jobma_login_df = pd.read_sql("SELECT * FROM jobma_login", engine) #Usage details
jobma_catcher_df = pd.read_sql("SELECT * FROM jobma_catcher", engine) #Usage details
jobma_login_df.shape, jobma_catcher_df.shape
# Out:
# ((39321, 21), (7672, 75))

# %%
jobma_login_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39321 entries, 0 to 39320
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   jobma_login_id       39321 non-null  int64
#  1   jobma_user_name      39321 non-null  object
#  2   jobma_password       39321 non-null  object
#  3   jobma_role_id        39321 non-null  int64
#  4   jobma_user_id        39321 non-null  int64
#  5   jobma_last_login     37785 non-null  object
#  6   jobma_created_by     7854 non-null   object
#  7   confirmed            39321 non-null  int64
#  8   confirmation_code    39321 non-null  object
#  9   jobma_login_status   7924 non-null   object
#  10  jobma_login_ip       39321 non-null  object
#  11  forget_password      245 non-null    object
#  12  remember_token       39321 non-null  object
#  13  jobma_social_login   39321 non-null  int64
#  14  password_changed_at  39321 non-null  datetime64[ns]
# ...

# %%
jobma_login_df.isna().sum()
# Out:
# jobma_login_id             0
# jobma_user_name            0
# jobma_password             0
# jobma_role_id              0
# jobma_user_id              0
# jobma_last_login        1536
# jobma_created_by       31467
# confirmed                  0
# confirmation_code          0
# jobma_login_status     31397
# jobma_login_ip             0
# forget_password        39076
# remember_token             0
# jobma_social_login         0
# password_changed_at        0
# deleted_at             39237
# created_at                 0
# updated_at                 0
# google2fa_secret       39321
# two_factor_status          0
# two_factor_type            0
# dtype: int64

# %%
jobma_login_df.isna().sum().sort_values(ascending=False).head(7)
# Out:
# google2fa_secret      39321
# deleted_at            39237
# forget_password       39076
# jobma_created_by      31467
# jobma_login_status    31397
# jobma_last_login       1536
# jobma_user_id             0
# dtype: int64

# %%
jobma_login_df.T
# Out:
#                                         0      \
# jobma_login_id                              1
# jobma_user_name      existinguser@example.com
# jobma_password                 hashedpassword
# jobma_role_id                               4
# jobma_user_id                            1001
# jobma_last_login                         None
# jobma_created_by                         None
# confirmed                                   1
# confirmation_code                           1
# jobma_login_status                          0
# jobma_login_ip
# forget_password                             1
# remember_token
# jobma_social_login                          0
# password_changed_at       2020-10-30 03:57:14
# deleted_at                                NaT
# created_at                2024-09-26 16:21:36
# updated_at                2024-09-26 16:21:36
# google2fa_secret                         None
# two_factor_status                           0
# two_factor_type                             0
#
# ...

# %%
jobma_login_df.nunique()
# Out:
# jobma_login_id         39321
# jobma_user_name        38484
# jobma_password         38519
# jobma_role_id              7
# jobma_user_id          38637
# jobma_last_login       18232
# jobma_created_by           3
# confirmed                  2
# confirmation_code       2838
# jobma_login_status         3
# jobma_login_ip          3179
# forget_password            2
# remember_token          5299
# jobma_social_login         2
# password_changed_at    29403
# deleted_at                35
# created_at             36902
# updated_at             36448
# google2fa_secret           0
# two_factor_status          2
# two_factor_type            2
# dtype: int64

# %%
jobma_login_df['jobma_login_id'].value_counts()
# Out:
# jobma_login_id
# 112393    1
# 1         1
# 240       1
# 535       1
# 642       1
#          ..
# 6591      1
# 6138      1
# 4691      1
# 4320      1
# 4261      1
# Name: count, Length: 39321, dtype: int64

# %%
jobma_login_df['jobma_user_id'].value_counts()
# Out:
# jobma_user_id
# 0          470
# 1115527     35
# 1115509     19
# 1115275     15
# 1115355     11
#           ...
# 1127089      1
# 1127091      1
# 1127093      1
# 1127095      1
# 117          1
# Name: count, Length: 38637, dtype: int64

# %%
jobma_login_df.columns
# Out:
# Index(['jobma_login_id', 'jobma_user_name', 'jobma_password', 'jobma_role_id',
#        'jobma_user_id', 'jobma_last_login', 'jobma_created_by', 'confirmed',
#        'confirmation_code', 'jobma_login_status', 'jobma_login_ip',
#        'forget_password', 'remember_token', 'jobma_social_login',
#        'password_changed_at', 'deleted_at', 'created_at', 'updated_at',
#        'google2fa_secret', 'two_factor_status', 'two_factor_type'],
#       dtype='object')

# %%
# Check for duplicate jobma_user_id count
print("No of duplicate catcher_id ----", jobma_login_df['jobma_user_name'].duplicated().sum())

#top most duplicates
print("Top duplicated jobma_user_id ----")
print(jobma_login_df['jobma_user_name'].value_counts().head(10))
# Out:
# No of duplicate catcher_id ---- 837
# Top duplicated jobma_user_id ----
# jobma_user_name
#                                         468
# thisisemail1423143ww4@mailinator.com     35
# nameee                                   25
# thisisemail123434@mailinator.com         19
# stringasdgh@yopmail.com                  15
# dummy@yopmail.com                        11
# sssrs123pkmkb@yopmail.com                11
# thisisemail1231434@mailinator.com         8
# test287382@yopmail.com                    8
# tets283782@yopmail.com                    8
# Name: count, dtype: int64

# %%
column_data = jobma_login_df['jobma_user_name']
print(jobma_login_df.shape)
print("No of unique values----",column_data.nunique(dropna=False), "\n")
print("Unique values ---------",column_data.unique(), "\n")
print(column_data.value_counts(dropna=False).head(10), "\n")
# Out:
# (39321, 21)
# No of unique values---- 38484
#
# Unique values --------- ['existinguser@example.com' 'superadmin@mailinator.com'
#  'gaurava@selectsourceintl.com' ... 'pratikabc10@yopmail.com'
#  'ramesh23@yopmail.com' 'ramesh21@yopmail.com']
#
# jobma_user_name
#                                         468
# thisisemail1423143ww4@mailinator.com     35
# nameee                                   25
# thisisemail123434@mailinator.com         19
# stringasdgh@yopmail.com                  15
# dummy@yopmail.com                        11
# sssrs123pkmkb@yopmail.com                11
# thisisemail1231434@mailinator.com         8
# test287382@yopmail.com                    8
# tets283782@yopmail.com                    8
# Name: count, dtype: int64

# %%
jobma_login_selected_df=jobma_login_df[[#'jobma_login_id',        #@39321 id
                                        'jobma_user_name',       # name
                                        # 'jobma_password',        # password
                                        'jobma_role_id',         #@7, 4,3,5,0,9,1,2 id----------------------------->>
                                        'jobma_user_id',         # id
                                        # 'jobma_last_login',      #@18233 almost 0000.000, None--------------------->> 
                                        # 'jobma_created_by',      #@4, NOne, 1, 0, 2-------------------------------->>
                                        'confirmed',             # 0,1-----1
                                        # 'confirmation_code',     #mostly null and email...
                                        # 'jobma_login_status',    #@4  -,0,1----------------------------------------->>
                                        # 'jobma_login_ip',        
                                        # 'forget_password',       
                                        # 'remember_token',        
                                        # 'jobma_social_login',    #2,  0,1---->0
                                        # 'password_changed_at',   
                                        # 'deleted_at',            #39237 is NAt value----------------------------------------------->>required all below three columns to know tenure of client
                                        # 'created_at',            ##---------------------------------------------------------------->> to find user tenure
                                        # 'updated_at',            ##----------------------------------------------------------------->>
                                        # 'google2fa_secret',      
                                        # 'two_factor_status',     #@0,1----->0
                                        # 'two_factor_type'        #@0,1----->0
                                       ]].copy()

# %%
jobma_login_selected_df
# Out:
#                      jobma_user_name  jobma_role_id  jobma_user_id  confirmed
# 0           existinguser@example.com              4           1001          1
# 1          superadmin@mailinator.com              1            162          1
# 2       gaurava@selectsourceintl.com              5             96          0
# 3      SMandeep@selectsourceintl.com              5            557          0
# 4                 ywangb13@gmail.com              4            908          1
# ...                              ...            ...            ...        ...
# 39316         pratikabc9@yopmail.com              4        1127089          1
# 39317        pratikabc10@yopmail.com              4        1127091          1
# 39318           ramesh23@yopmail.com              4        1127093          1
# 39319           ramesh21@yopmail.com              4        1127095          1
# 39320         Sergebrian@yopmail.com              3           9445          1
#
# [39321 rows x 4 columns]

# %%
jobma_login_selected_df['number_of_logins'] = jobma_login_selected_df['jobma_user_name'].map(jobma_login_selected_df['jobma_user_name'].value_counts())

# %%
jobma_login_selected_df
# Out:
#                      jobma_user_name  jobma_role_id  jobma_user_id  confirmed  \
# 0           existinguser@example.com              4           1001          1
# 1          superadmin@mailinator.com              1            162          1
# 2       gaurava@selectsourceintl.com              5             96          0
# 3      SMandeep@selectsourceintl.com              5            557          0
# 4                 ywangb13@gmail.com              4            908          1
# ...                              ...            ...            ...        ...
# 39316         pratikabc9@yopmail.com              4        1127089          1
# 39317        pratikabc10@yopmail.com              4        1127091          1
# 39318           ramesh23@yopmail.com              4        1127093          1
# 39319           ramesh21@yopmail.com              4        1127095          1
# 39320         Sergebrian@yopmail.com              3           9445          1
#
#        number_of_logins
# ...

# %%
jobma_login_selected_df.shape, jobma_login_df.shape
# Out:
# ((39321, 5), (39321, 21))

# %%
jobma_login_selected_df.head(10)
# Out:
#                  jobma_user_name  jobma_role_id  jobma_user_id  confirmed  \
# 0       existinguser@example.com              4           1001          1
# 1      superadmin@mailinator.com              1            162          1
# 2   gaurava@selectsourceintl.com              5             96          0
# 3  SMandeep@selectsourceintl.com              5            557          0
# 4             ywangb13@gmail.com              4            908          1
# 5            teresamcf@gmail.com              4            924          1
# 6                     hr@3spl.in              3            106          1
# 7           krishnak@dtawave.com              5            117          1
# 8     aviationindustry@job4u.com              3            124          1
# 9      joboportunities@job4u.com              3            125          1
#
#    number_of_logins
# 0                 1
# 1                 1
# 2                 1
# 3                 2
# 4                 1
# 5                 1
# ...

# %%
jobma_catcher_df=jobma_catcher_df[['jobma_catcher_id','jobma_catcher_email']]

# %%
jobma_catcher_df.rename(columns={'jobma_catcher_email': 'jobma_user_name'}, inplace=True)

# %%
jobma_catcher_df.rename(columns={'jobma_catcher_id': 'catcher_id'}, inplace=True)

# %%
jobma_catcher_df
# Out:
#       catcher_id                jobma_user_name
# 0              1         jayant_kks@yopmail.com
# 1             92      jobs@selectsourceintl.com
# 2             96   gaurava@selectsourceintl.com
# 3            106                     hr@3spl.in
# 4            117           krishnak@dtawave.com
# ...          ...                            ...
# 7667        9437      ownDataNew12312@jobma.com
# 7668        9439   checkEvaluate12312@jobma.com
# 7669        9441  sessionChange312312@jobma.com
# 7670        9443         nayan23@mailinator.com
# 7671        9445         Sergebrian@yopmail.com
#
# [7672 rows x 2 columns]

# %%
jobma_login_df= jobma_catcher_df.merge(jobma_login_selected_df,
                                       on='jobma_user_name',
                                       how='outer')

# %%
jobma_login_df.shape
# Out:
# (39946, 6)

# %%
jobma_login_df
# Out:
#        catcher_id              jobma_user_name  jobma_role_id  jobma_user_id  \
# 0           987.0                                         5.0          890.0
# 1           987.0                                         0.0            0.0
# 2           987.0                                         0.0            0.0
# 3           987.0                                         0.0            0.0
# 4           987.0                                         0.0            0.0
# ...           ...                          ...            ...            ...
# 39941         NaN          zxdfhbd@yopmail.com            4.0        62961.0
# 39942         NaN  zxncbew42q43@mailinator.com            4.0      1112244.0
# 39943         NaN               zz@yopmail.com            4.0        86818.0
# 39944         NaN        zzzzzrrrr@yopmail.com            4.0        79731.0
# 39945         NaN          Àbh8@mailinator.com            4.0        80790.0
#
#        confirmed  number_of_logins
# ...

# %%
jobma_login_df=jobma_login_df[['catcher_id', 'confirmed', 'number_of_logins']]

# %%
jobma_login_df
# Out:
#        catcher_id  confirmed  number_of_logins
# 0           987.0        0.0             468.0
# 1           987.0        0.0             468.0
# 2           987.0        0.0             468.0
# 3           987.0        0.0             468.0
# 4           987.0        0.0             468.0
# ...           ...        ...               ...
# 39941         NaN        1.0               1.0
# 39942         NaN        1.0               1.0
# 39943         NaN        1.0               1.0
# 39944         NaN        1.0               1.0
# 39945         NaN        0.0               1.0
#
# [39946 rows x 3 columns]

# %%
jobma_catcher_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
jobma_login_df.duplicated().sum()
# Out:
# np.int64(32233)

# %%
jobma_login_df.drop_duplicates(inplace=True)
# Out:
# C:\Users\SSI\AppData\Local\Temp\ipykernel_11016\3717868385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobma_login_df.drop_duplicates(inplace=True)

# %%
jobma_login_df.shape, jobma_catcher_df.shape
# Out:
# ((7713, 3), (7672, 2))

# %%
jobma_login_df.isna().sum()
# Out:
# catcher_id          19
# confirmed           36
# number_of_logins    36
# dtype: int64

# %%
8760-1066, 7694-7672
# Out:
# (7694, 22)

# %%
jobma_login_df.dropna(inplace=True)
# Out:
# C:\Users\SSI\AppData\Local\Temp\ipykernel_11016\2917073290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobma_login_df.dropna(inplace=True)

# %%
jobma_login_df.shape
# Out:
# (7658, 3)

# %%
jobma_login_df=jobma_login_df.astype(int)

# %%
jobma_login_df.isna().sum()
# Out:
# catcher_id          0
# confirmed           0
# number_of_logins    0
# dtype: int64

# %%
jobma_login_df.nunique(dropna=False)
# Out:
# catcher_id          7636
# confirmed              2
# number_of_logins       6
# dtype: int64

# %%
jobma_login_df
# Out:
#        catcher_id  confirmed  number_of_logins
# 0             987          0               468
# 468          5270          0               468
# 940          8422          1                 1
# 941          8423          1                 1
# 943          8424          1                 1
# ...           ...        ...               ...
# 39929        7180          1                 1
# 39935        7141          1                 1
# 39937        3850          1                 1
# 39938        7172          1                 1
# 39939        3735          1                 1
#
# [7658 rows x 3 columns]

# %%
jobma_login_df['number_of_logins'].unique()
# Out:
# array([468,   1,   2,   3,   4,   5])

# %%
jobma_login_df.to_csv("login_df.csv", index=False)
