# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
jobma_catcher_df = pd.read_sql("SELECT * FROM jobma_catcher", engine)

# %%
jobma_catcher_df.to_csv('jobma_catcher_df.csv', index=False)
# Out:
#       jobma_catcher_id                   jobma_catcher_fname  \
# 0                    1                                jayant
# 1                   92
# 2                   96                                Gaurav
# 3                  106
# 4                  117                               Krishna
# ...                ...                                   ...
# 7667              9437            new own data account check
# 7668              9439         new account to check evaluate
# 7669              9441  new account to check changed session
# 7670              9443                                 nayan
# 7671              9445                           Serge brian
#
#      jobma_catcher_lname jobma_catcher_dob jobma_catcher_video_status  \
# 0                                     None                       None
# 1                               2016-11-22                          1
# 2                  Arora        2016-11-01                          1
# ...

# %%
jobma_catcher_df.to_csv('jobma_catcher_df.csv', index=False)

# %%
jobma_login_df = pd.read_sql("SELECT * FROM jobma_login", engine)

# %%
jobma_login_df.to_csv('jobma_login_df.csv', index=False)

# %%
jobma_wallet_df = pd.read_sql("SELECT * FROM wallet", engine)

# %%
jobma_wallet_df.to_csv('jobma_wallet_df.csv', index=False)

# %%
jobma_subscription_df = pd.read_sql("SELECT * FROM subscription_history", engine)

# %%
jobma_subscription_df.to_csv('jobma_subscription_df.csv', index=False)
print("Done")
# Out:
# Done

# %%
jobma_catcher_language_df = pd.read_sql("SELECT * FROM jobma_catcher_language", engine)

# %%
jobma_catcher_language_df.to_csv('jobma_catcher_language_df.csv', index=False)
print("Done")
# Out:
# Done
