# %% [markdown]
# # jobma_interviews_df

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
#candidate interview response data (just for pre-recorded type)
jobma_interviews_df = pd.read_sql("SELECT * FROM jobma_interviews", engine)

# %%
jobma_interviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21999 entries, 0 to 21998
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           21999 non-null  int64
#  1   jobma_post_id                21999 non-null  int64
#  2   jobma_pitcher_id             21999 non-null  int64
#  3   jobma_catcher_id             21999 non-null  int64
#  4   interview_applied_id         21999 non-null  int64
#  5   jobma_invitation_id          21999 non-null  int64
#  6   jobma_interview_question_id  21999 non-null  int64
#  7   jobma_answers                21998 non-null  object
#  8   jobma_video_answer           1685 non-null   object
#  9   retake_requested             21999 non-null  int64
#  10  payment_status               21999 non-null  object
#  11  interview_rate               21999 non-null  float64
#  12  interview_credit             19008 non-null  float64
#  13  view_date                    15082 non-null  object
#  14  subscription_type            21999 non-null  object
#  15  interview_cost_type          21999 non-null  object
#  16  evaluated_by                 20292 non-null  float64
#  17  is_streaming                 21999 non-null  object
#  18  deleted_at                   3957 non-null   datetime64[ns]
#  19  created_at                   21999 non-null  object
#  20  updated_at                   21999 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(8), object(9)
# memory usage: 3.5+ MB

# %%
jobma_interviews_df.shape
# Out:
# (21999, 21)

# %%
jobma_interviews_df.isna().sum().sort_values(ascending=False)
# Out:
# jobma_video_answer             20314
# deleted_at                     18042
# view_date                       6917
# interview_credit                2991
# evaluated_by                    1707
# jobma_answers                      1
# interview_applied_id               0
# jobma_pitcher_id                   0
# jobma_post_id                      0
# id                                 0
# jobma_catcher_id                   0
# jobma_invitation_id                0
# jobma_interview_question_id        0
# interview_rate                     0
# payment_status                     0
# retake_requested                   0
# subscription_type                  0
# interview_cost_type                0
# is_streaming                       0
# created_at                         0
# updated_at                         0
# dtype: int64

# %%
jobma_interviews_selected_df=jobma_interviews_df[['id',#@21999
                                                  'jobma_post_id',#@3916
                                                  # 'jobma_pitcher_id',#@15360
                                                  'jobma_catcher_id',#@865
                                                  # 'interview_applied_id', #@19057
                                                  # 'jobma_invitation_id', #@19044
                                                  # 'jobma_interview_question_id',#1 

                                                  
                                                  # 'jobma_answers',# @19621 dict of question ans
                                                  # 'jobma_video_answer',#@1 none,-

                                                  # 'retake_requested', #@2 0,1-->0
                                                  # 'payment_status', #@2 1,0--->1
                                                  'interview_rate',######################@81 0.0,1.0,2.0,3.0,4.0,....10.0............>>

                                                  'interview_credit',#@58  0.0,1.0,....10.0 ----->1.0
                                                  # 'view_date', ###################################
                                                  # 'subscription_type',#@3 0,1,_, ---->0

                                                  # 'interview_cost_type', #@2 0,1
                                                  'evaluated_by', #@684 who evaluated the candidate may be ,,,, 0.0,Nan, 7151, 2335,...
                                                  # 'is_streaming', #@4   1,3,0,2---->1
                                                  
                                                  # 'deleted_at',
                                                  # 'created_at', 
                                                  # 'updated_at'
                                                 ]].copy()

# %%
jobma_interviews_selected_df.isna().sum()
# Out:
# id                     0
# jobma_post_id          0
# jobma_catcher_id       0
# interview_rate         0
# interview_credit    2991
# evaluated_by        1707
# dtype: int64

# %%
jobma_interviews_selected_df
# Out:
#           id  jobma_post_id  jobma_catcher_id  interview_rate  \
# 0          1            774               127             1.0
# 1          2            774               127             1.0
# 2          3            776               127             1.0
# 3          4            776               127             1.0
# 4          5            776               127             1.0
# ...      ...            ...               ...             ...
# 21994  28305              0              8464             1.0
# 21995  28307          30687              8597             2.0
# 21996  28309              0              8893             4.0
# 21997  28311              0              8464             1.0
# 21998  28313          35855              8464             1.0
#
#        interview_credit  evaluated_by
# 0                   2.0           0.0
# 1                   2.0           0.0
# 2                   2.0           0.0
# 3                   2.0           0.0
# 4                   2.0           0.0
# ...                 ...           ...
# 21994               1.0        8464.0
# 21995               2.0        8597.0
# 21996               4.0        8893.0
# 21997               1.0        8464.0
# 21998               1.0        8464.0
#
# [21999 rows x 6 columns]

# %%
jobma_interviews_selected_df.shape, jobma_interviews_df.shape
# Out:
# ((21999, 6), (21999, 21))
