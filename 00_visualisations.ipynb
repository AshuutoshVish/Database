# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler

# %%
df=pd.read_csv("pre_final_database.csv")

# %%
df.shape
# Out:
# (5529, 37)

# %%
df.describe().T
# Out:
#                            count           mean           std   min      25%  \
# catcher_id                5529.0    4768.240369  2.431389e+03  92.0  2774.00
# jobma_catcher_title       5529.0       0.234943  7.777441e-01   0.0     0.00
# jobma_catcher_status      5529.0       0.908663  3.016102e-01  -1.0     1.00
# jobma_catcher_type        5529.0       0.922590  2.672651e-01   0.0     1.00
# is_premium                5529.0       0.378188  4.849787e-01   0.0     0.00
# jobma_verified            5529.0       0.999096  3.006108e-02   0.0     1.00
# subscription_status       5529.0       1.887864  3.178470e-01   0.0     2.00
# sub_user                  5529.0     279.376379  1.927332e+03   0.0     1.00
# live_interview_credit     5529.0       1.423505  1.367551e+01   0.0     1.00
# pre_recorded_credit       5529.0       3.383758  1.352060e+02   0.0     1.00
# ai_live_interview_credit  5529.0       1.000181  1.344859e-02   1.0     1.00
# interview_cost_type       5529.0       0.651474  4.765466e-01   0.0     0.00
# referral_credit           5529.0       8.337855  5.972085e+02   0.0     0.00
# ai_live_interview         5529.0       0.001266  3.556231e-02   0.0     0.00
# days_since_creation       5529.0    1554.517092  6.764796e+02   0.0  1065.00
# confirmed                 5529.0       0.928920  2.569813e-01   0.0     1.00
# number_of_logins          5529.0       1.106348  6.284146e+00   1.0     1.00
# credit_amount             5529.0      33.997605  4.796887e+02   0.0     0.00
# wallet_amount             5529.0  162018.622897  3.008652e+06   0.0    50.00
# plan_type                 5529.0       0.432266  4.954357e-01   0.0     0.00
# is_unlimited              5529.0       0.143064  3.501696e-01   0.0     0.00
# trial_account_type        5529.0       0.059504  2.365878e-01   0.0     0.00
# billing_cycle_status      5529.0       0.000543  2.328942e-02   0.0     0.00
# subscription_amount       5529.0   16480.039564  2.473427e+05   0.0    24.96
# credit_given              5529.0      49.328269  2.917763e+02   0.0     0.00
# currency_val              5529.0       1.977976  8.306666e+00   0.0     1.00
# times_of_subscription     5529.0       1.986616  4.597021e+00   1.0     1.00
# kits_count                5529.0       2.605173  1.280215e+02   0.0     0.00
# position_created          5529.0       1.512751  1.861719e+01   0.0     0.00
# number_of_invitations     5529.0       8.709893  1.025543e+02   0.0     0.00
# pitchers_counts           5529.0       6.570266  2.403006e+02   0.0     0.00
# def_interview_counts      5529.0       3.347260  3.706586e+01   0.0     0.00
# interview_counts          5529.0       0.170194  3.278246e+00   0.0     0.00
# ai_interview_counts       5529.0       0.013384  9.039439e-01   0.0     0.00
#
#                              50%     75%          max
# catcher_id                4794.0  6914.0      9445.00
# jobma_catcher_title          0.0     0.0         8.00
# jobma_catcher_status         1.0     1.0         1.00
# jobma_catcher_type           1.0     1.0         1.00
# is_premium                   0.0     1.0         1.00
# jobma_verified               1.0     1.0         1.00
# subscription_status          2.0     2.0         2.00
# sub_user                     5.0   103.0    140000.00
# live_interview_credit        1.0     1.0      1000.00
# pre_recorded_credit          1.0     1.0      9999.99
# ai_live_interview_credit     1.0     1.0         2.00
# interview_cost_type          1.0     1.0         1.00
# referral_credit              0.0     0.0     44400.00
# ai_live_interview            0.0     0.0         1.00
# days_since_creation       1482.0  1853.0      4511.00
# confirmed                    1.0     1.0         1.00
# number_of_logins             1.0     1.0       468.00
# credit_amount                0.0     0.0     11800.00
# wallet_amount              150.0  1100.0  99999999.99
# plan_type                    0.0     1.0         1.00
# is_unlimited                 0.0     0.0         1.00
# trial_account_type           0.0     0.0         1.00
# billing_cycle_status         0.0     0.0         1.00
# subscription_amount        199.0  4788.0  13933333.00
# credit_given                 0.0     0.0     10000.00
# currency_val                 1.0     1.0        71.87
# times_of_subscription        1.0     2.0       238.00
# kits_count                   0.0     0.0      9504.00
# position_created             0.0     0.0       825.00
# number_of_invitations        0.0     0.0      3396.00
# pitchers_counts              0.0     0.0     17640.00
# def_interview_counts         0.0     0.0      1069.00
# interview_counts             0.0     0.0       150.00
# ai_interview_counts          0.0     0.0        67.00

# %%
df.describe(include='all')
# Out:
#          catcher_id  jobma_catcher_title jobma_catcher_otype  \
# count   5529.000000          5529.000000                5529
# unique          NaN                  NaN                   7
# top             NaN                  NaN                   1
# freq            NaN                  NaN                5297
# mean    4768.240369             0.234943                 NaN
# std     2431.388564             0.777744                 NaN
# min       92.000000             0.000000                 NaN
# 25%     2774.000000             0.000000                 NaN
# 50%     4794.000000             0.000000                 NaN
# 75%     6914.000000             0.000000                 NaN
# max     9445.000000             8.000000                 NaN
#
#         jobma_catcher_status  jobma_catcher_type   is_premium  jobma_verified  \
# count            5529.000000         5529.000000  5529.000000     5529.000000
# unique                   NaN                 NaN          NaN             NaN
# top                      NaN                 NaN          NaN             NaN
# freq                     NaN                 NaN          NaN             NaN
# mean                0.908663            0.922590     0.378188        0.999096
# std                 0.301610            0.267265     0.484979        0.030061
# min                -1.000000            0.000000     0.000000        0.000000
# 25%                 1.000000            1.000000     0.000000        1.000000
# 50%                 1.000000            1.000000     0.000000        1.000000
# 75%                 1.000000            1.000000     1.000000        1.000000
# max                 1.000000            1.000000     1.000000        1.000000
#
#         subscription_status       sub_user per_sub_user  ...  credit_given  \
# count           5529.000000    5529.000000         5529  ...   5529.000000
# unique                  NaN            NaN            9  ...           NaN
# top                     NaN            NaN          100  ...           NaN
# freq                    NaN            NaN         3098  ...           NaN
# mean               1.887864     279.376379          NaN  ...     49.328269
# std                0.317847    1927.332416          NaN  ...    291.776292
# min                0.000000       0.000000          NaN  ...      0.000000
# 25%                2.000000       1.000000          NaN  ...      0.000000
# 50%                2.000000       5.000000          NaN  ...      0.000000
# 75%                2.000000     103.000000          NaN  ...      0.000000
# max                2.000000  140000.000000          NaN  ...  10000.000000
#
#         currency_val  times_of_subscription   kits_count  position_created  \
# count    5529.000000            5529.000000  5529.000000       5529.000000
# unique           NaN                    NaN          NaN               NaN
# top              NaN                    NaN          NaN               NaN
# freq             NaN                    NaN          NaN               NaN
# mean        1.977976               1.986616     2.605173          1.512751
# std         8.306666               4.597021   128.021540         18.617189
# min         0.000000               1.000000     0.000000          0.000000
# 25%         1.000000               1.000000     0.000000          0.000000
# 50%         1.000000               1.000000     0.000000          0.000000
# 75%         1.000000               2.000000     0.000000          0.000000
# max        71.870000             238.000000  9504.000000        825.000000
#
#        number_of_invitations  pitchers_counts  def_interview_counts  \
# count            5529.000000      5529.000000           5529.000000
# unique                   NaN              NaN                   NaN
# top                      NaN              NaN                   NaN
# freq                     NaN              NaN                   NaN
# mean                8.709893         6.570266              3.347260
# std               102.554300       240.300559             37.065864
# min                 0.000000         0.000000              0.000000
# 25%                 0.000000         0.000000              0.000000
# 50%                 0.000000         0.000000              0.000000
# 75%                 0.000000         0.000000              0.000000
# max              3396.000000     17640.000000           1069.000000
#
#         interview_counts  ai_interview_counts
# count        5529.000000          5529.000000
# unique               NaN                  NaN
# top                  NaN                  NaN
# freq                 NaN                  NaN
# mean            0.170194             0.013384
# std             3.278246             0.903944
# min             0.000000             0.000000
# 25%             0.000000             0.000000
# 50%             0.000000             0.000000
# 75%             0.000000             0.000000
# max           150.000000            67.000000
#
# [11 rows x 37 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                           catcher_id  jobma_catcher_title  \
# catcher_id                  1.000000            -0.035389
# jobma_catcher_title        -0.035389             1.000000
# jobma_catcher_status        0.129206            -0.071220
# jobma_catcher_type          0.252906             0.076197
# is_premium                 -0.621303             0.057424
# jobma_verified             -0.032328            -0.052809
# subscription_status        -0.360213            -0.050738
# sub_user                   -0.079656             0.036912
# live_interview_credit      -0.018921            -0.008472
# pre_recorded_credit         0.016790            -0.005022
# ai_live_interview_credit   -0.016017            -0.004063
# interview_cost_type        -0.044370            -0.011843
# referral_credit            -0.015318            -0.003089
# ai_live_interview           0.046333             0.008865
# days_since_creation        -0.925744             0.034543
# confirmed                   0.282209             0.010257
# number_of_logins           -0.019556             0.014392
# credit_amount              -0.067472            -0.021414
# wallet_amount               0.021503            -0.010967
# plan_type                   0.084268            -0.156575
# is_unlimited                0.210199            -0.033105
# trial_account_type          0.051182             0.224841
# billing_cycle_status        0.008770             0.032909
# subscription_amount         0.014159            -0.018907
# credit_given                0.220420             0.034915
# currency_val               -0.144965            -0.035796
# times_of_subscription       0.056769            -0.019005
# kits_count                 -0.015107            -0.003683
# position_created           -0.034153             0.008807
# number_of_invitations      -0.007959            -0.018117
# pitchers_counts            -0.026898            -0.006592
# def_interview_counts        0.002234            -0.014841
# interview_counts           -0.026953            -0.002631
# ai_interview_counts        -0.013644            -0.003959
#
#                           jobma_catcher_status  jobma_catcher_type  \
# catcher_id                            0.129206            0.252906
# jobma_catcher_title                  -0.071220            0.076197
# jobma_catcher_status                  1.000000            0.260110
# jobma_catcher_type                    0.260110            1.000000
# is_premium                           -0.138529           -0.090905
# jobma_verified                       -0.009112           -0.008715
# subscription_status                   0.087502           -0.078778
# sub_user                             -0.046047           -0.033508
# live_interview_credit                 0.008681            0.010011
# pre_recorded_credit                   0.005039            0.005208
# ai_live_interview_credit              0.004073            0.003896
# interview_cost_type                  -0.113279           -0.049951
# referral_credit                       0.004229            0.004044
# ai_live_interview                     0.010783            0.010313
# days_since_creation                  -0.253851           -0.407433
# confirmed                             0.065594           -0.069592
# number_of_logins                      0.004935            0.004472
# credit_amount                         0.020774            0.020532
# wallet_amount                         0.010130            0.010919
# plan_type                             0.106889            0.132531
# is_unlimited                          0.014126            0.035239
# trial_account_type                    0.038152            0.021365
# billing_cycle_status                  0.007057            0.006749
# subscription_amount                   0.016461            0.009498
# credit_given                          0.000197            0.048976
# currency_val                          0.035876            0.035899
# times_of_subscription                -0.071857            0.046714
# kits_count                            0.003095            0.005620
# position_created                     -0.005897            0.017140
# number_of_invitations                -0.010103            0.023699
# pitchers_counts                       0.001011            0.003673
# def_interview_counts                 -0.012648            0.012009
# interview_counts                      0.001454            0.014420
# ai_interview_counts                   0.004485            0.004289
#
#                           is_premium  jobma_verified  subscription_status  \
# catcher_id                 -0.621303       -0.032328            -0.360213
# jobma_catcher_title         0.057424       -0.052809            -0.050738
# jobma_catcher_status       -0.138529       -0.009112             0.087502
# jobma_catcher_type         -0.090905       -0.008715            -0.078778
# is_premium                  1.000000        0.011055             0.124952
# jobma_verified              0.011055        1.000000             0.027250
# subscription_status         0.124952        0.027250             1.000000
# sub_user                    0.096171       -0.001977             0.009521
# live_interview_credit      -0.005530        0.000932             0.008243
# pre_recorded_credit        -0.010882        0.000441            -0.037786
# ai_live_interview_credit    0.017246        0.000405            -0.037574
# interview_cost_type        -0.022098       -0.009378             0.095440
# referral_credit             0.017029       -0.000588            -0.039006
# ai_live_interview          -0.017278        0.001071            -0.099465
# days_since_creation         0.597145        0.038212             0.346430
# confirmed                  -0.245839       -0.008322            -0.075453
# number_of_logins            0.017072        0.000509             0.002711
# credit_amount              -0.017683        0.002132             0.022265
# wallet_amount               0.007320       -0.001386            -0.032674
# plan_type                  -0.133913       -0.010187             0.103394
# is_unlimited               -0.101350       -0.039262            -0.086630
# trial_account_type         -0.145714        0.007568             0.040637
# billing_cycle_status       -0.002155        0.000701            -0.040654
# subscription_amount         0.011099        0.001274             0.015767
# credit_given               -0.102198        0.003024            -0.143246
# currency_val                0.071125        0.003542             0.042640
# times_of_subscription       0.048845        0.002530            -0.221771
# kits_count                  0.020901       -0.002725            -0.043628
# position_created            0.058560       -0.003373            -0.050383
# number_of_invitations       0.054446       -0.007596            -0.107217
# pitchers_counts             0.026904       -0.000004            -0.012580
# def_interview_counts        0.063447       -0.003615            -0.120053
# interview_counts            0.035059       -0.000274            -0.059631
# ai_interview_counts         0.016099        0.000445            -0.041367
#
#                           sub_user  live_interview_credit  \
# catcher_id               -0.079656              -0.018921
# jobma_catcher_title       0.036912              -0.008472
# jobma_catcher_status     -0.046047               0.008681
# jobma_catcher_type       -0.033508               0.010011
# is_premium                0.096171              -0.005530
# jobma_verified           -0.001977               0.000932
# subscription_status       0.009521               0.008243
# sub_user                  1.000000              -0.003923
# live_interview_credit    -0.003923               1.000000
# pre_recorded_credit      -0.002392               0.100685
# ai_live_interview_credit  0.005022               0.000567
# interview_cost_type       0.007240               0.021168
# referral_credit           0.004996               0.000551
# ai_live_interview         0.000196               0.000757
# days_since_creation       0.103005               0.009744
# confirmed                -0.069449              -0.050088
# number_of_logins          0.004972              -0.000468
# credit_amount            -0.010082               0.064530
# wallet_amount             0.002892               0.002311
# plan_type                -0.038753               0.033037
# is_unlimited              0.068735              -0.012122
# trial_account_type       -0.013624              -0.006392
# billing_cycle_status      0.004715              -0.000154
# subscription_amount      -0.005856              -0.001693
# credit_given             -0.020425              -0.005320
# currency_val              0.015139               0.000464
# times_of_subscription    -0.006164              -0.000075
# kits_count                0.005071               0.000442
# position_created          0.012200              -0.000510
# number_of_invitations    -0.000465              -0.000947
# pitchers_counts           0.006060              -0.000601
# def_interview_counts      0.004484              -0.001564
# interview_counts          0.011972               0.001535
# ai_interview_counts       0.004809               0.000522
#
#                           pre_recorded_credit  ...  credit_given  \
# catcher_id                           0.016790  ...      0.220420
# jobma_catcher_title                 -0.005022  ...      0.034915
# jobma_catcher_status                 0.005039  ...      0.000197
# jobma_catcher_type                   0.005208  ...      0.048976
# is_premium                          -0.010882  ...     -0.102198
# jobma_verified                       0.000441  ...      0.003024
# subscription_status                 -0.037786  ...     -0.143246
# sub_user                            -0.002392  ...     -0.020425
# live_interview_credit                0.100685  ...     -0.005320
# pre_recorded_credit                  1.000000  ...     -0.000413
# ai_live_interview_credit             0.000161  ...     -0.002274
# interview_cost_type                 -0.016655  ...      0.028281
# referral_credit                      0.000153  ...     -0.001286
# ai_live_interview                   -0.000176  ...      0.000082
# days_since_creation                 -0.010654  ...     -0.181288
# confirmed                           -0.001046  ...      0.045926
# number_of_logins                    -0.000293  ...     -0.001855
# credit_amount                        0.005500  ...     -0.011984
# wallet_amount                        0.000406  ...     -0.008058
# plan_type                           -0.008040  ...     -0.106464
# is_unlimited                        -0.006895  ...     -0.053696
# trial_account_type                  -0.004294  ...     -0.034523
# billing_cycle_status                -0.000181  ...     -0.003939
# subscription_amount                 -0.001090  ...      0.026285
# credit_given                        -0.000413  ...      1.000000
# currency_val                        -0.001683  ...     -0.020277
# times_of_subscription                0.000935  ...      0.006626
# kits_count                           0.000087  ...     -0.002342
# position_created                    -0.001037  ...     -0.007390
# number_of_invitations               -0.000993  ...     -0.004797
# pitchers_counts                     -0.000368  ...     -0.002379
# def_interview_counts                -0.000901  ...     -0.003900
# interview_counts                    -0.000551  ...      0.009405
# ai_interview_counts                  0.000136  ...     -0.001989
#
#                           currency_val  times_of_subscription  kits_count  \
# catcher_id                   -0.144965               0.056769   -0.015107
# jobma_catcher_title          -0.035796              -0.019005   -0.003683
# jobma_catcher_status          0.035876              -0.071857    0.003095
# jobma_catcher_type            0.035899               0.046714    0.005620
# is_premium                    0.071125               0.048845    0.020901
# jobma_verified                0.003542               0.002530   -0.002725
# subscription_status           0.042640              -0.221771   -0.043628
# sub_user                      0.015139              -0.006164    0.005071
# live_interview_credit         0.000464              -0.000075    0.000442
# pre_recorded_credit          -0.001683               0.000935    0.000087
# ai_live_interview_credit     -0.001584               0.690582    0.998297
# interview_cost_type           0.078671              -0.010387   -0.019824
# referral_credit              -0.001644               0.690511    0.998469
# ai_live_interview            -0.004192               0.262353    0.389301
# days_since_creation           0.103604              -0.056034    0.002789
# confirmed                    -0.208631               0.037630    0.003540
# number_of_logins             -0.002031              -0.003357   -0.000214
# credit_amount                -0.008378               0.002835    0.002002
# wallet_amount                -0.006302               0.002894    0.003905
# plan_type                     0.130815              -0.001351   -0.010451
# is_unlimited                 -0.048980               0.018833   -0.005834
# trial_account_type           -0.032838              -0.049831   -0.005018
# billing_cycle_status         -0.002743               0.395446    0.576276
# subscription_amount          -0.007824               0.004185   -0.000945
# credit_given                 -0.020277               0.006626   -0.002342
# currency_val                  1.000000              -0.023822   -0.001861
# times_of_subscription        -0.023822               1.000000    0.699715
# kits_count                   -0.001861               0.699715    1.000000
# position_created             -0.004392               0.376600    0.416868
# number_of_invitations         0.029731               0.420960    0.371072
# pitchers_counts              -0.002916               0.054977    0.046326
# def_interview_counts         -0.008995               0.327915    0.257246
# interview_counts             -0.001922               0.413089    0.482747
# ai_interview_counts          -0.001744               0.688815    0.995738
#
#                           position_created  number_of_invitations  \
# catcher_id                       -0.034153              -0.007959
# jobma_catcher_title               0.008807              -0.018117
# jobma_catcher_status             -0.005897              -0.010103
# jobma_catcher_type                0.017140               0.023699
# is_premium                        0.058560               0.054446
# jobma_verified                   -0.003373              -0.007596
# subscription_status              -0.050383              -0.107217
# sub_user                          0.012200              -0.000465
# live_interview_credit            -0.000510              -0.000947
# pre_recorded_credit              -0.001037              -0.000993
# ai_live_interview_credit          0.394118               0.331873
# interview_cost_type              -0.019879              -0.024493
# referral_credit                   0.395063               0.333949
# ai_live_interview                 0.174706               0.179804
# days_since_creation               0.023479              -0.009183
# confirmed                        -0.002438               0.013968
# number_of_logins                  0.000438              -0.000903
# credit_amount                     0.000055               0.003681
# wallet_amount                     0.021968               0.056702
# plan_type                        -0.019073               0.033693
# is_unlimited                      0.018547              -0.001635
# trial_account_type               -0.019865              -0.019769
# billing_cycle_status              0.393626               0.190398
# subscription_amount              -0.003299              -0.001710
# credit_given                     -0.007390              -0.004797
# currency_val                     -0.004392               0.029731
# times_of_subscription             0.376600               0.420960
# kits_count                        0.416868               0.371072
# position_created                  1.000000               0.500133
# number_of_invitations             0.500133               1.000000
# pitchers_counts                   0.659011               0.128731
# def_interview_counts              0.420307               0.826286
# interview_counts                  0.492332               0.565974
# ai_interview_counts               0.393099               0.333657
#
#                           pitchers_counts  def_interview_counts  \
# catcher_id                      -0.026898              0.002234
# jobma_catcher_title             -0.006592             -0.014841
# jobma_catcher_status             0.001011             -0.012648
# jobma_catcher_type               0.003673              0.012009
# is_premium                       0.026904              0.063447
# jobma_verified                  -0.000004             -0.003615
# subscription_status             -0.012580             -0.120053
# sub_user                         0.006060              0.004484
# live_interview_credit           -0.000601             -0.001564
# pre_recorded_credit             -0.000368             -0.000901
# ai_live_interview_credit         0.040383              0.217974
# interview_cost_type              0.006050             -0.021699
# referral_credit                  0.040867              0.220798
# ai_live_interview                0.019179              0.106848
# days_since_creation              0.030974             -0.005996
# confirmed                        0.005203              0.011556
# number_of_logins                -0.000153              0.000172
# credit_amount                   -0.000568              0.002096
# wallet_amount                    0.029907              0.195098
# plan_type                       -0.007558              0.035266
# is_unlimited                    -0.004455              0.004269
# trial_account_type              -0.006846             -0.022511
# billing_cycle_status             0.022927              0.124677
# subscription_amount             -0.001056             -0.000732
# credit_given                    -0.002379             -0.003900
# currency_val                    -0.002916             -0.008995
# times_of_subscription            0.054977              0.327915
# kits_count                       0.046326              0.257246
# position_created                 0.659011              0.420307
# number_of_invitations            0.128731              0.826286
# pitchers_counts                  1.000000              0.153942
# def_interview_counts             0.153942              1.000000
# interview_counts                 0.103506              0.530135
# ai_interview_counts              0.040548              0.219715
#
#                           interview_counts  ai_interview_counts
# catcher_id                       -0.026953            -0.013644
# jobma_catcher_title              -0.002631            -0.003959
# jobma_catcher_status              0.001454             0.004485
# jobma_catcher_type                0.014420             0.004289
# is_premium                        0.035059             0.016099
# jobma_verified                   -0.000274             0.000445
# subscription_status              -0.059631            -0.041367
# sub_user                          0.011972             0.004809
# live_interview_credit             0.001535             0.000522
# pre_recorded_credit              -0.000551             0.000136
# ai_live_interview_credit          0.462954             0.996786
# interview_cost_type              -0.031616            -0.020245
# referral_credit                   0.467781             0.996793
# ai_live_interview                 0.302280             0.415893
# days_since_creation               0.010829             0.001191
# confirmed                        -0.007755             0.004096
# number_of_logins                 -0.000422            -0.000251
# credit_amount                     0.001906             0.002025
# wallet_amount                     0.005265            -0.000777
# plan_type                        -0.014676            -0.012921
# is_unlimited                      0.027006            -0.006050
# trial_account_type               -0.013060            -0.003725
# billing_cycle_status              0.266528             0.575369
# subscription_amount              -0.002404            -0.000959
# credit_given                      0.009405            -0.001989
# currency_val                     -0.001922            -0.001744
# times_of_subscription             0.413089             0.688815
# kits_count                        0.482747             0.995738
# position_created                  0.492332             0.393099
# number_of_invitations             0.565974             0.333657
# pitchers_counts                   0.103506             0.040548
# def_interview_counts              0.530135             0.219715
# interview_counts                  1.000000             0.468727
# ai_interview_counts               0.468727             1.000000
#
# [34 rows x 34 columns]

# %%
plt.figure(figsize=(20, 18))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt='.2f')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualising Sub_user

# %%
df['sub_user'].value_counts().tail(20)
# Out:
# sub_user
# 37        1
# 123       1
# 35        1
# 130       1
# 64        1
# 63        1
# 65        1
# 145       1
# 107       1
# 120       1
# 19        1
# 113       1
# 116       1
# 140000    1
# 29        1
# 24        1
# 73        1
# 53        1
# 23        1
# 1001      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['sub_user'])
plt.title('Boxplot of sub_user')
plt.show()

# %%
plt.figure(figsize=(30,5))
sns.countplot(x=df['sub_user'])
# Out:
# <Axes: xlabel='sub_user', ylabel='count'>

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['live_interview_credit'])
# Out:
# <Axes: xlabel='live_interview_credit'>

# %%
plt.figure(figsize=(25,8))
sns.countplot(x=df['live_interview_credit'])
# Out:
# <Axes: xlabel='live_interview_credit', ylabel='count'>

# %%
#Pre_recorded_credit

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['pre_recorded_credit'])
# Out:
# <Axes: xlabel='pre_recorded_credit'>

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=df['pre_recorded_credit'])
# Out:
# <Axes: xlabel='pre_recorded_credit', ylabel='count'>

# %%
#Credit_given

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df['credit_given'])
# Out:
# <Axes: xlabel='credit_given'>

# %%
plt.figure(figsize=(25,5))
sns.countplot(x=df['credit_given'])
# Out:
# <Axes: xlabel='credit_given', ylabel='count'>

# %%
#now currency_val

# %%
plt.figure(figsize=(20,4))
sns.boxplot(x=df['currency_val'])
# Out:
# <Axes: xlabel='currency_val'>

# %%
plt.figure(figsize=(10,4))
sns.countplot(x=df['currency_val'])
# Out:
# <Axes: xlabel='currency_val', ylabel='count'>

# %%
#referral_credit

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x=df['referral_credit'])
# Out:
# <Axes: xlabel='referral_credit'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['referral_credit'])
# Out:
# <Axes: xlabel='referral_credit', ylabel='count'>

# %%
sns.histplot(data=df['jobma_catcher_title'])
# Out:
# <Axes: xlabel='jobma_catcher_title', ylabel='Count'>

# %%
sns.histplot(data=df['days_since_creation'])
# Out:
# <Axes: xlabel='days_since_creation', ylabel='Count'>

# %%
df.hist(bins=40, figsize=(25, 15))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 5))
sns.boxplot(data=df.iloc[:, :18])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 5))
sns.boxplot(data=df.iloc[:, 18:])
plt.tight_layout()
plt.show()

# %%
subset_cols = df.select_dtypes(include=['float64', 'int64']).columns[:10]
sns.pairplot(df[subset_cols], hue=None)
plt.show()

# %%
sns.countplot(x=df['jobma_catcher_status'])
# Out:
# <Axes: xlabel='jobma_catcher_status', ylabel='count'>

# %%
sns.countplot(x=df['jobma_catcher_otype'])
# Out:
# <Axes: xlabel='jobma_catcher_otype', ylabel='count'>

# %%
sns.countplot(x=df['jobma_verified'])
# Out:
# <Axes: xlabel='jobma_verified', ylabel='count'>

# %%
sns.countplot(x=df['subscription_status'])
# Out:
# <Axes: xlabel='subscription_status', ylabel='count'>

# %%
sns.countplot(x=df['company_size'])
# Out:
# <Axes: xlabel='company_size', ylabel='count'>

# %%
sns.countplot(x=df['plan_type'])
# Out:
# <Axes: xlabel='plan_type', ylabel='count'>

# %%
sns.countplot(x=df['is_unlimited'])
# Out:
# <Axes: xlabel='is_unlimited', ylabel='count'>

# %%
sns.countplot(x=df['confirmed'])
# Out:
# <Axes: xlabel='confirmed', ylabel='count'>

# %%
sns.countplot(x=df['interview_cost_type'])
# Out:
# <Axes: xlabel='interview_cost_type', ylabel='count'>

# %%
sns.histplot(df['wallet_amount'], bins=30)
# Out:
# <Axes: xlabel='wallet_amount', ylabel='Count'>

# %%
sns.histplot(df['subscription_amount'], bins=30)
# Out:
# <Axes: xlabel='subscription_amount', ylabel='Count'>

# %%
sns.histplot(df['days_since_creation'], bins=30)
# Out:
# <Axes: xlabel='days_since_creation', ylabel='Count'>

# %%
sns.histplot(df['pitchers_counts'], bins=30)
# Out:
# <Axes: xlabel='pitchers_counts', ylabel='Count'>

# %%
sns.histplot(df['number_of_logins'], bins=30)
# Out:
# <Axes: xlabel='number_of_logins', ylabel='Count'>

# %%
sns.histplot(df['kits_count'], bins=10)
# Out:
# <Axes: xlabel='kits_count', ylabel='Count'>

# %%
sns.histplot(df['position_created'], bins=40)
# Out:
# <Axes: xlabel='position_created', ylabel='Count'>

# %%
sns.barplot(x='company_size', y='wallet_amount', data=df)
# Out:
# <Axes: xlabel='company_size', ylabel='wallet_amount'>

# %%
sns.barplot(x='company_size', y='wallet_amount', data=df)
# Out:
# <Axes: xlabel='company_size', ylabel='wallet_amount'>

# %%
plt.figure(figsize=(25, 5))
sns.barplot(x='subscription_amount', y='is_premium', hue='plan_type', data=df)
# Out:
# <Axes: xlabel='subscription_amount', ylabel='is_premium'>

# %%
df['subscription_bin'] = pd.cut(df['subscription_amount'], bins=10)
plt.figure(figsize=(20,5))
sns.barplot(x='subscription_bin', y='is_premium', data=df)
# Out:
# <Axes: xlabel='subscription_bin', ylabel='is_premium'>

# %%
sns.boxplot(x='is_premium', y='wallet_amount', data=df)
# Out:
# <Axes: xlabel='is_premium', ylabel='wallet_amount'>

# %%
wallet_counts = df['wallet_amount'].value_counts().sort_index()
plt.figure(figsize=(10,5))
sns.barplot(x=wallet_counts.index, y=wallet_counts.values)
plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='live_interview_credit', data=df)
plt.title('Count of Live Interview Credits')
plt.xlabel('Live Interview Credit')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='number_of_logins', data=df)
plt.title('Count of Live Interview Credits')
plt.xlabel('Live Interview Credit')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Boxplot for checking the extreme outliers

# %%
plt.figure(figsize=(30,5))
sns.boxplot(df.iloc[:, :17])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(30,5))
sns.boxplot(df.iloc[:, 17:])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(30, 5))
sns.boxplot(df.iloc[:, 17:])
plt.tight_layout()
plt.show()

# %%
cols_to_check = ['wallet_amount', 'subscription_amount', 'credit_given', 'pre_recorded_credit']
for col in cols_to_check:
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
df[wallet_amount]
# Out:
# ['wallet_amount', 'subscription_amount', 'credit_given', 'pre_recorded_credit']

# %%
df['wallet_amount'].nunique()
# Out:
# 714

# %%
df['pre_recorded_credit'].nunique()
# Out:
# 29

# %%
df['credit_given'].nunique()
# Out:
# 29

# %%
df[['credit_given', 'pre_recorded_credit']].head(10)
# Out:
#    credit_given  pre_recorded_credit
# 0             0                  1.0
# 1             0                  1.0
# 2             0                  1.0
# 3             0                  1.0
# 4             0                  1.0
# 5             0                  1.0
# 6             0                  1.0
# 7             0                  1.0
# 8             0                  1.0
# 9             0                  1.0
