# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Jobma%40123@localhost:3306/jobma")

# %%
catcher_df = pd.read_sql("SELECT * FROM jobma_catcher where jobma_catcher_parent=0", con=engine)
catcher_df.shape
# Out:
# (5546, 75)

# %%
catcher_df.rename(columns={"jobma_catcher_id": "catcher_id"}, inplace=True)

# %%
def fill_missing_dates(df, target_col, source_col, missing_value="0000-00-00"):
    mask = (df[target_col] == missing_value) | (df[target_col].isna())
    df.loc[mask, target_col] = df.loc[mask, source_col].astype(str)
    return df
catcher_df = fill_missing_dates(catcher_df, 'jobma_catcher_creation', 'created_at')

# %%
catcher_df.columns
# Out:
# Index(['catcher_id', 'jobma_catcher_fname', 'jobma_catcher_lname',
#        'jobma_catcher_dob', 'jobma_catcher_video_status',
#        'jobma_catcher_company', 'org_type', 'sec_ques_id', 'security_ans',
#        'jobma_about_company', 'jobma_functional', 'jobma_catcher_indus',
#        'jobma_company_email', 'jobma_catcher_email', 'jobma_catcher_title',
#        'jobma_catcher_ext', 'jobma_catcher_otype', 'jobma_catcher_photo',
#        'jobma_catcher_logo', 'jobma_catcher_website', 'jobma_company_address',
#        'jobma_catcher_address2', 'jobma_catcher_video', 'jobma_catcher_city',
#        'jobma_catcher_state', 'jobma_catcher_country', 'jobma_catcher_zip',
#        'jobma_catcher_fax', 'jobma_catcher_phone', 'jobma_catcher_status',
#        'jobma_catcher_creation', 'jobma_catcher_type',
#        'jobma_catcher_sub_accounts', 'is_premium', 'jobma_catcher_parent',
#        'jobma_catcher_is_deleted', 'jobma_verified', 'jobma_in_index',
#        'data_access', 'subscription_status', 'interview_rate',
#        'remember_token', 'deleted_at', 'api_key', 'sub_user', 'per_sub_user',
#        'live_interview_credit', 'pre_recorded_credit',
#        'ai_live_interview_credit', 'credit_value', 'interview_cost_type',
#        'subscription_type', 'phone_call_cost_type',
#        'call_and_regording_credits', 'transcription_credits',
#        'temp_subscription_type', 'created_at', 'updated_at',
#        'jobma_support_rtc', 'interview_question', 'video_recording_suppport',
#        'subaccount_permission', 'reply_email', 'sing_up_canditate_after_apply',
#        'currency', 'referral_credit', 'company_size', 'theme', 'flag',
#        'jobma_auto_recording_status', 'jobma_scenario_question_status',
#        'ai_live_interview', 'ms_teams_chat_reference', 'bot_audio',
#        'approval'],
#       dtype='object')

# %%
df =catcher_df[['catcher_id',
                'jobma_catcher_title',
                'jobma_catcher_otype',
                'jobma_catcher_status',
                'jobma_catcher_creation',
                'jobma_catcher_type',
                'is_premium',
                'subscription_status',
                'sub_user',
                'per_sub_user',
                'subscription_type',
                'created_at',
                'referral_credit',
                'company_size',
                'ai_live_interview',
               ]].copy()

# %%
df[['jobma_catcher_creation','created_at']].tail(40)
# Out:
#      jobma_catcher_creation          created_at
# 5506    2024-04-08 10:15:21 2024-04-08 10:15:21
# Group-based fill: use the most common value of company_size within each subscription_status
df['company_size'] = df.groupby(['subscription_status', 'sub_user','is_premium'])['company_size'].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else '1-25'))

# %%
df['company_size'].value_counts(dropna=False)
# Out:
# company_size
# 1-25              2648
# 26-100            1531
# 101-500            895
# 500-1000           387
# More than 1000      85
# Name: count, dtype: int64

# %%
df['jobma_catcher_type'].value_counts(dropna=False)
# Out:
# jobma_catcher_type
# 1       4951
# 0        428
# None     167
# Name: count, dtype: int64

# %%
df['jobma_catcher_type'] = df.groupby(['company_size', 'sub_user', 'catcher_id'])['jobma_catcher_type'].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else '0'))

# %%
df['jobma_catcher_type'].value_counts(dropna=False)
# Out:
# jobma_catcher_type
# 1    4951
# 0     595
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# catcher_id              0
# jobma_catcher_title     0
# jobma_catcher_otype     0
# jobma_catcher_status    4
# jobma_catcher_type      0
# is_premium              0
# subscription_status     0
# sub_user                0
# per_sub_user            0
# subscription_type       0
# referral_credit         0
# company_size            0
# ai_live_interview       0
# days_since_creation     0
# dtype: int64

# %%
df['jobma_catcher_status'].value_counts()
# Out:
# jobma_catcher_status
# 1     5057
# 0      463
# -1      22
# Name: count, dtype: int64

# %%
df['jobma_catcher_status'] = pd.to_numeric(df['jobma_catcher_status'], errors='coerce')
df['jobma_catcher_status'] = df['jobma_catcher_status'].fillna(0)
df.loc[df['jobma_catcher_status'] < 0, 'jobma_catcher_status'] = 0

# %%
df.isna().sum()
# Out:
# catcher_id              0
# jobma_catcher_title     0
# jobma_catcher_otype     0
# jobma_catcher_status    0
# jobma_catcher_type      0
# is_premium              0
# subscription_status     0
# sub_user                0
# per_sub_user            0
# subscription_type       0
# referral_credit         0
# company_size            0
# ai_live_interview       0
# days_since_creation     0
# dtype: int64

# %%
df['ai_live_interview'].value_counts()
# Out:
# ai_live_interview
# 0    5539
# 1       7
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (5546, 14)

# %%
df['referral_credit'].value_counts()
# Out:
# referral_credit
# 0        5538
# 100         3
# 200         2
# 44400       1
# 400         1
# 600         1
# Name: count, dtype: int64

# %%
df.loc[df['referral_credit'] > 0, 'referral_credit'] = 1

# %%
df['referral_credit'].value_counts()
# Out:
# referral_credit
# 0    5538
# 1       8
# Name: count, dtype: int64

# %%
df['jobma_catcher_otype'].value_counts(dropna=False)
# Out:
# jobma_catcher_otype
#                    5104
# 1                   206
# 2                   101
# Employer            100
# Recruiting Firm      28
# Ad Agency             5
# 101                   1
# 18                    1
# Name: count, dtype: int64

# %%
df['sub_user'].value_counts(dropna=False).head(20)
# Out:
# sub_user
# 1      2079
# 999    1365
# 10      873
# 2       266
# 100     200
# 0       183
# 3       140
# 4        83
# 5        69
# 11       49
# 6        25
# 60       23
# 12       22
# 13       16
# 14       15
# 15       11
# 7        11
# 9        11
# 22        8
# 16        7
# Name: count, dtype: int64

# %%
df['sub_user'] = df['sub_user'].apply(lambda x: 105 if x > 105 else x)

# %%
df.nunique()
# Out:
# catcher_id              5546
# jobma_catcher_title        9
# jobma_catcher_otype        8
# jobma_catcher_status       2
# jobma_catcher_type         2
# is_premium                 3
# subscription_status        3
# sub_user                  48
# per_sub_user               9
# subscription_type          2
# referral_credit            2
# company_size               5
# ai_live_interview          2
# days_since_creation     1139
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                       catcher_id  jobma_catcher_title  jobma_catcher_status  \
# catcher_id              1.000000            -0.035432              0.122304
# jobma_catcher_title    -0.035432             1.000000             -0.070195
# jobma_catcher_status    0.122304            -0.070195              1.000000
# sub_user               -0.353763             0.155889             -0.204048
# referral_credit         0.040771             0.086233              0.011819
# days_since_creation    -0.928790             0.057654             -0.251636
#
#                       sub_user  referral_credit  days_since_creation
# catcher_id           -0.353763         0.040771            -0.928790
# jobma_catcher_title   0.155889         0.086233             0.057654
# jobma_catcher_status -0.204048         0.011819            -0.251636
# sub_user              1.000000         0.011770             0.461255
# referral_credit       0.011770         1.000000            -0.041806
# days_since_creation   0.461255        -0.041806             1.000000

# %%
df.describe().T
# Out:
#                        count         mean          std   min      25%     50%  \
# catcher_id            5546.0  4766.986116  2432.980364  92.0  2772.25  4791.5
# jobma_catcher_title   5546.0     0.235485     0.777786   0.0     0.00     0.0
# jobma_catcher_status  5546.0     0.911828     0.283570   0.0     1.00     1.0
# sub_user              5546.0    33.239272    45.651476   0.0     1.00     5.0
# referral_credit       5546.0     0.001442     0.037956   0.0     0.00     0.0
# days_since_creation   5546.0  1573.206996   649.138560  22.0  1070.00  1487.0
#
#                           75%     max
# catcher_id            6914.75  9445.0
# jobma_catcher_title      0.00     8.0
# jobma_catcher_status     1.00     1.0
# sub_user               105.00   105.0
# referral_credit          0.00     1.0
# days_since_creation   1858.00  4516.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5546 entries, 0 to 5545
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   catcher_id            5546 non-null   int64
#  1   jobma_catcher_title   5546 non-null   int64
#  2   jobma_catcher_otype   5546 non-null   object
#  3   jobma_catcher_status  5546 non-null   float64
#  4   jobma_catcher_type    5546 non-null   object
#  5   is_premium            5546 non-null   object
#  6   subscription_status   5546 non-null   object
#  7   sub_user              5546 non-null   int64
#  8   per_sub_user          5546 non-null   object
#  9   subscription_type     5546 non-null   object
#  10  referral_credit       5546 non-null   int64
#  11  company_size          5546 non-null   object
#  12  ai_live_interview     5546 non-null   object
#  13  days_since_creation   5546 non-null   int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 606.7+ KB

# %%
numeric_df = df.select_dtypes(include='number')

# %%
import matplotlib.pyplot as plt

numeric_df.hist(figsize=(12, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
numeric_df.plot(kind='box', subplots=True, layout=(2, 3), figsize=(12, 8), sharex=False, sharey=False)
plt.tight_layout()
plt.show()
