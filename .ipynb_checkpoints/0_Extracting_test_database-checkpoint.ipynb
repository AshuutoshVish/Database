# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:Jobma%40123@localhost:3306/test")
catcher = pd.read_sql("SELECT * FROM jobma_catcher where jobma_catcher_parent=0", con=engine)
catcher_data= pd.read_sql("SELECT * FROM jobma_catcher", con=engine)
login = pd.read_sql("SELECT * FROM jobma_login", con=engine)
wallet = pd.read_sql("SELECT * FROM wallet", con=engine)
subscription = pd.read_sql("SELECT * FROM subscription_history", con=engine)


pre_recorded_kit= pd.read_sql("SELECT * FROM job_assessment_kit", engine)
job_posting = pd.read_sql("SELECT * FROM jobma_employer_job_posting", engine)
invitations = pd.read_sql("Select * FROM jobma_pitcher_invitations", engine)

# pre_rec_interviews_df = pd.read_sql("SELECT * FROM jobma_interviews", engine) 
# live_interviews_df = pd.read_sql("SELECT * FROM jobma_interviews_online", engine)

# %% [markdown]
# # Catcher

# %%
print(catcher.shape)
# Out:
# (4466, 69)

# %%
catcher_df=catcher[['jobma_catcher_id',
                    'company_size',#1-25,26-100
                    'currency',#0,1
                    'is_premium',#0
                    'subscription_status',#2
                    'jobma_catcher_status']]#1

#Sub_user #0, 17, 11, 10, 7
#wallet_#60,50
#is_unlimited #0
#plan_type#0,1
#
#subcription_count #1
#invitation #0
# pre_recorded_kit_counts #0

# %%
sub_users_df = catcher_data.groupby('jobma_catcher_parent').size().reset_index(name='sub_users')

# %%
sub_users_df.sort_values(by="sub_users", ascending=False).head(40)
# Out:
#      jobma_catcher_parent  sub_users
# 0                       0       4466
# 815                  9095         40
# 827                  9579         24
# 333                  5335         17
# 677                  7810         17
# 450                  6014         16
# 778                  8501         14
# 788                  8609         13
# 743                  8334         13
# 79                   3678         13
# 792                  8715         13
# 744                  8351         12
# 482                  6227         11
# 574                  6977         11
# 855                  9757         11
# 741                  8287         11
# 451                  6017         10
# 875                  9869         10
# 823                  9377         10
# 460                  6042         10
# 742                  8329          9
# 525                  6543          9
# 352                  5416          9
# 701                  7972          8
# 275                  5073          7
# 536                  6688          7
# 2                    2957          7
# 724                  8180          7
# 26                   3131          7
# 934                 10121          7
# 369                  5564          7
# 95                   3777          6
# 268                  4968          6
# 202                  4244          6
# 796                  8742          6
# 25                   3125          5
# 795                  8741          5
# 821                  9225          5
# 874                  9863          5
# 426                  5909          5

# %%
catcher_df = catcher_df.merge(sub_users_df, 
                              left_on='jobma_catcher_id', 
                              right_on='jobma_catcher_parent', 
                              how='left'
                             )

# %%
catcher_df.shape
# Out:
# (4466, 8)

# %%
catcher_df = catcher_df.drop(columns=['jobma_catcher_parent'])

# %%
catcher_df.shape
# Out:
# (4466, 7)

# %%
catcher_df['sub_users'].max()
# Out:
# np.float64(40.0)

# %%
catcher_df.isna().sum()
# Out:
# jobma_catcher_id           0
# company_size               3
# currency                   0
# is_premium                 0
# subscription_status        0
# jobma_catcher_status       0
# sub_users               3460
# dtype: int64

# %%
catcher_df['sub_users']=catcher_df['sub_users'].fillna(0)

# %%
mode_value = catcher_df['company_size'].mode()[0]
catcher_df['company_size'] = catcher_df['company_size'].fillna(mode_value)

# %%
catcher_df.isna().sum()
# Out:
# jobma_catcher_id        0
# company_size            0
# currency                0
# is_premium              0
# subscription_status     0
# jobma_catcher_status    0
# sub_users               0
# dtype: int64

# %%
catcher_df.max()
# Out:
# jobma_catcher_id                 10536
# company_size            More than 1000
# currency                             1
# is_premium                           1
# subscription_status                  2
# jobma_catcher_status                 1
# sub_users                         40.0
# dtype: object

# %%
catcher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4466 entries, 0 to 4465
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   jobma_catcher_id      4466 non-null   int64
#  1   company_size          4466 non-null   object
#  2   currency              4466 non-null   object
#  3   is_premium            4466 non-null   object
#  4   subscription_status   4466 non-null   object
#  5   jobma_catcher_status  4466 non-null   object
#  6   sub_users             4466 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 244.4+ KB

# %%
catcher_df
# Out:
#       jobma_catcher_id company_size currency is_premium subscription_status  \
# 0                 2656         1-25        1          0                   1
# 1                 2935       26-100        1          0                   2
# 2                 2937      101-500        1          0                   2
# 3                 2938       26-100        1          0                   1
# 4                 2939       26-100        1          0                   2
# ...                ...          ...      ...        ...                 ...
# 4461             10529         1-25        0          0                   1
# 4462             10530         1-25        0          0                   1
# 4463             10531       26-100        0          0                   1
# 4464             10533         1-25        0          0                   1
# 4465             10536         1-25        0          0                   1
#
#      jobma_catcher_status  sub_users
# 0                       1        1.0
# 1                       1        0.0
# 2                       1        0.0
# 3                       1        0.0
# 4                       1        0.0
# ...                   ...        ...
# 4461                    1        0.0
# 4462                    1        0.0
# 4463                    1        0.0
# 4464                    1        0.0
# 4465                    1        0.0
#
# [4466 rows x 7 columns]

# %% [markdown]
# # Login_df Not used nowwww

# %%
login.columns
# Out:
# Index(['jobma_login_id', 'jobma_user_name', 'jobma_password', 'jobma_role_id',
#        'jobma_user_id', 'jobma_last_login', 'jobma_created_by', 'confirmed',
#        'confirmation_code', 'jobma_login_status', 'jobma_login_ip',
#        'forget_password', 'remember_token', 'jobma_social_login',
#        'password_changed_at', 'deleted_at', 'created_at', 'updated_at'],
#       dtype='object')

# %%
login_df=login[['jobma_login_id',
                'jobma_user_id', ##may be join the table
                'jobma_user_name',
                'jobma_login_status',
                'jobma_last_login',#to know last login
                'deleted_at', #last login
                'updated_at']]#for last login

# %%
# login_df.head(20)

# %% [markdown]
# # Wallet_df

# %%
catcher_df.shape, wallet.shape
# Out:
# ((4466, 7), (4479, 12))

# %%
wallet.nunique()
# Out:
# id                    4479
# catcher_id            4479
# credit_amount            0
# wallet_amount          180
# subscription_type        2
# plan_type                3
# is_unlimited             3
# premium_storage          1
# trial_account_type       2
# gst_code               370
# created_at            4471
# updated_at            4375
# dtype: int64

# %%
wallet_df=wallet[['catcher_id',
                  'wallet_amount',
                  'is_unlimited',
                  'plan_type']]

# %%
# wallet_df.sort_values(by="wallet_amount", ascending=False).head(20)

# %%
wallet_df.shape
# Out:
# (4479, 4)

# %%
wallet_df.nunique()
# Out:
# catcher_id       4479
# wallet_amount     180
# is_unlimited        3
# plan_type           3
# dtype: int64

# %%
wallet_df.isna().sum()
# Out:
# catcher_id       0
# wallet_amount    0
# is_unlimited     0
# plan_type        0
# dtype: int64

# %%
wallet_df = wallet_df.rename(columns={'catcher_id': 'jobma_catcher_id'})

# %%
catcher_df = catcher_df.merge(wallet_df, 
                              on='jobma_catcher_id', 
                              how='inner'
                             )

# %%
catcher_df.shape
# Out:
# (4461, 10)

# %%
catcher_df.isna().sum()
# Out:
# jobma_catcher_id        0
# company_size            0
# currency                0
# is_premium              0
# subscription_status     0
# jobma_catcher_status    0
# sub_users               0
# wallet_amount           0
# is_unlimited            0
# plan_type               0
# dtype: int64

# %% [markdown]
# # subscription

# %%
catcher_df.shape, subscription.shape
# Out:
# ((4461, 10), (9493, 34))

# %%
# subscription_df=subscription[['catcher_id', 'premium_plan_id', 'subscription_amount', 'credit_given', 'currency', 'currency_val']]

# %%
subscription_df = subscription.groupby('catcher_id').agg(subscription_sum=('subscription_amount', 'sum'),
                                                            subscription_count=('catcher_id', 'count'),
                                                            ).reset_index()

# %%
subscription_df.shape
# Out:
# (4477, 3)

# %%
subscription_df = subscription_df.rename(columns={'catcher_id': 'jobma_catcher_id'})

# %%
subscription_df.shape, catcher_df.shape
# Out:
# ((4477, 3), (4461, 10))

# %%
catcher_df = catcher_df.merge(subscription_df, 
                              on='jobma_catcher_id', 
                              how='inner'
                             )

# %%
catcher_df.shape
# Out:
# (4461, 12)

# %%
catcher_df.isna().sum()
# Out:
# jobma_catcher_id        0
# company_size            0
# currency                0
# is_premium              0
# subscription_status     0
# jobma_catcher_status    0
# sub_users               0
# wallet_amount           0
# is_unlimited            0
# plan_type               0
# subscription_sum        0
# subscription_count      0
# dtype: int64

# %% [markdown]
# # invitations

# %%
invitations.shape
# Out:
# (84848, 44)

# %%
# invitations

# %%
invitation_df = invitations.groupby('jobma_catcher_id').size().reset_index(name='invitations')

# %%
invitation_df.sort_values(by="invitations", ascending=False).head(10)
# Out:
#       jobma_catcher_id  invitations
# 1016             10063        50046
# 796               9579         1465
# 308               5943         1347
# 460               6543         1204
# 349               6014         1172
# ...                ...          ...
# 209               5600            1
# 210               5606            1
# 211               5608            1
# 213               5618            1
# 217               5635            1
#
# [1171 rows x 2 columns]

# %%
invitation_df.shape, catcher_df.shape
# Out:
# ((1171, 2), (4461, 12))

# %%
catcher_df=catcher_df.merge(invitation_df,
                           on="jobma_catcher_id",
                           how="left")

# %%
catcher_df.shape
# Out:
# (4461, 13)

# %% [markdown]
# # pre_recorded_kit

# %%
pre_recorded_kit.shape
# Out:
# (5661, 25)

# %%
pre_recorded_kit_df = pre_recorded_kit.groupby('catcher_id').size().reset_index(name='pre_recorded_kit_counts')

# %%
pre_recorded_kit_df = pre_recorded_kit_df.rename(columns={'catcher_id': 'jobma_catcher_id'})

# %%
pre_recorded_kit_df.shape, catcher_df.shape
# Out:
# ((1192, 2), (4461, 13))

# %%
pre_recorded_kit_df.sort_values(by='pre_recorded_kit_counts', ascending=False).head(10)
# Out:
#       jobma_catcher_id  pre_recorded_kit_counts
# 784               9095                      292
# 329               5943                      197
# 1051             10121                      162
# 333               5947                      151
# 274               5814                      124

# %%
pre_recorded_kit_df.max()
# Out:
# jobma_catcher_id           10536
# pre_recorded_kit_counts      292
# dtype: int64

# %%
pre_recorded_kit_df.shape, catcher_df.shape
# Out:
# ((1192, 2), (4461, 13))

# %%
catcher_df.isna().sum().sum()
# Out:
# np.int64(3634)

# %%
catcher_df = catcher_df.merge(pre_recorded_kit_df, 
                              on='jobma_catcher_id', 
                              how='left'
                             )

# %%
catcher_df.shape
# Out:
# (4461, 14)

# %%
catcher_df.isna().sum()
# Out:
# jobma_catcher_id              0
# company_size                  0
# currency                      0
# is_premium                    0
# subscription_status           0
# jobma_catcher_status          0
# sub_users                     0
# wallet_amount                 0
# is_unlimited                  0
# plan_type                     0
# subscription_sum              0
# subscription_count            0
# invitations                3634
# pre_recorded_kit_counts    3444
# dtype: int64

# %% [markdown]
# # job_posting

# %%
job_posting.shape
# Out:
# (5069, 68)

# %%
job_posting_df = job_posting.groupby('jobma_catcher_id').size().reset_index(name='number_of_jobs_posted')

# %%
job_posting_df.sort_values(by='number_of_jobs_posted', ascending=False).head(10)
# Out:
#      jobma_catcher_id  number_of_jobs_posted
# 369              5893                    189
# 757              9095                    181
# 786              9579                    179
# 350              5854                    156
# 680              8497                    117

# %%
job_posting_df.shape, catcher_df.shape
# Out:
# ((1127, 2), (4461, 14))

# %%
catcher_df = catcher_df.merge(job_posting_df, 
                              on='jobma_catcher_id', 
                              how='left'
                             )

# %%
catcher_df.shape
# Out:
# (4461, 15)

# %%
catcher_df.head(20)
# Out:
#     jobma_catcher_id company_size currency is_premium subscription_status  \
# 0               2656         1-25        1          0                   1
# 1               2935       26-100        1          0                   2
# 2               2937      101-500        1          0                   2
# 3               2938       26-100        1          0                   1
# 4               2939       26-100        1          0                   2
# 5               2940       26-100        1          0                   2
# 6               2941       26-100        1          0                   2
# 7               2942         1-25        1          0                   2
# 8               2943         1-25        1          0                   2
# 9               2944      101-500        0          0                   2
# 10              2945       26-100        1          0                   2
# 11              2946      101-500        0          1                   2
# 12              2947     500-1000        1          0                   2
# 13              2948         1-25        1          0                   2
# 14              2949      101-500        1          0                   2
# 15              2950      101-500        0          1                   2
# 16              2951         1-25        1          1                   2
# 17              2952         1-25        1          1                   2
# 18              2953      101-500        1          0                   2
# 19              2954       26-100        1          0                   2
#
#    jobma_catcher_status  sub_users  wallet_amount is_unlimited plan_type  \
# 0                     1        1.0        66666.0            1         0
# 1                     1        0.0           60.0            0         1
# 2                     1        0.0           60.0            0         1
# 3                     1        0.0           50.0            0         1
# 4                     1        0.0           60.0            0         1
# 5                     1        0.0           60.0            0         1
# 6                     1        0.0           60.0            0         1
# 7                     1        0.0           60.0            0         1
# 8                     1        0.0           60.0            0         1
# 9                     1        0.0           60.0            0         0
# 10                    1        0.0           60.0            0         1
# 11                    1        0.0           60.0            0         0
# 12                    1        0.0           60.0            0         1
# 13                    1        0.0           60.0            0         1
# 14                    1        0.0           60.0            0         1
# 15                    1        0.0           60.0            0         0
# 16                    1        0.0           60.0            0         1
# 17                    1        0.0           60.0            0         1
# 18                    1        0.0           60.0            0         1
# 19                    1        0.0           60.0            0         1
#
#     subscription_sum  subscription_count  invitations  \
# 0           15000.00                   1          4.0
# 1              53.10                   1          NaN
# 2             118.00                   1          NaN
# 3           15200.18                   3          NaN
# 4           11800.00                   1          NaN
# 5              11.80                   1          NaN
# 6           11800.00                   1          NaN
# 7              11.80                   1          NaN
# 8              11.80                   1          NaN
# 9             199.00                   1          NaN
# 10            118.00                   1          NaN
# 11            100.00                   1          NaN
# 12             11.80                   1          NaN
# 13            118.00                   1          NaN
# 14            317.00                   2          NaN
# 15            100.00                   1          NaN
# 16            118.00                   1          NaN
# 17              1.00                   1          NaN
# 18             11.80                   1          NaN
# 19          11800.00                   1          NaN
#
#     pre_recorded_kit_counts  number_of_jobs_posted
# 0                       2.0                    1.0
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    1.0
# 4                       NaN                    1.0
# 5                       NaN                    1.0
# 6                       NaN                    1.0
# 7                       NaN                    NaN
# 8                       NaN                    1.0
# 9                       NaN                    NaN
# 10                      NaN                    NaN
# 11                      NaN                    NaN
# 12                      NaN                    1.0
# 13                      NaN                    NaN
# 14                      NaN                    2.0
# 15                      NaN                    NaN
# 16                      NaN                    NaN
# 17                      NaN                    NaN
# 18                      NaN                    1.0
# 19                      NaN                    1.0

# %%
catcher_df.isna().sum()
# Out:
# jobma_catcher_id              0
# company_size                  0
# currency                      0
# is_premium                    0
# subscription_status           0
# jobma_catcher_status          0
# sub_users                     0
# wallet_amount                 0
# is_unlimited                  0
# plan_type                     0
# subscription_sum              0
# subscription_count            0
# invitations                3634
# pre_recorded_kit_counts    3444
# number_of_jobs_posted      3579
# dtype: int64

# %%
catcher_df=catcher_df.fillna(0)

# %%
catcher_df.isna().sum()
# Out:
# jobma_catcher_id           0
# company_size               0
# currency                   0
# is_premium                 0
# subscription_status        0
# jobma_catcher_status       0
# sub_users                  0
# wallet_amount              0
# is_unlimited               0
# plan_type                  0
# subscription_sum           0
# subscription_count         0
# invitations                0
# pre_recorded_kit_counts    0
# number_of_jobs_posted      0
# dtype: int64

# %%
catcher_df.to_csv("Data_False.csv", index=False)
print("Done")
# Out:
# Done

# %%
# catcher_df.to_csv("Data_extraction.csv", index=False)
# print("Done")
