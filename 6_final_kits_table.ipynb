# %%
#working on kits to combine them and use them

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
ai_video_kit_df = pd.read_sql("SELECT * FROM ai_video_kit", engine)
pre_recorded_kit_df = pd.read_sql("SELECT * FROM job_assessment_kit", engine)

# %%
ai_video_kit_df.head(5)
# Out:
#    id  catcher_id       title        slug  answer_duration  \
# 0  13        1873      Jquery      jquery              300
# 1  14        1873       React     react-4             1800
# 2  15        1873         Kit         kit              300
# 3  16        1873      Python      python             1200
# 4  17        1873  Javascript  javascript              300
#
#                                         question_set  min_experience  \
# 0  [{"id":"1","ques":"Added question"},{"id":"2",...               0
# 1  [{"id":"1","ques":"Can you explain what React ...               1
# 2  [{"id":"1","ques":"Can you explain what React ...               2
# 3  [{"id":"1","ques":"Can you explain the differe...              29
# 4  [{"id":"1","ques":"Can you explain the differe...               1
#
#    max_experience interview_level              evaluation_keywords  is_active  \
# 0               2               2  ["Python", "Jquery", "Laravel"]          1
# ...

# %%
pre_recorded_kit_df.head(5)
# Out:
#    id  catcher_id       title        slug  answer_duration interview_type  \
# 0   3         908        test      test-2              NaN              1
# 1   5        1209         A@1        aat1              NaN              1
# 2  13        1209  test integ  test-integ              NaN              1
# 3  16        1209  test454667  test454667              NaN              1
# 4  22        1209     test555     test555              NaN              1
#
#                                         question_set pre_screening  \
# 0  {"question":[{"ques":"intro","ques_title":"","...          None
# 1  {"question":[{"ques":"intro","ques_title":"","...          None
# 2  {"question":[{"ques":"intro","ques_title":"","...          None
# 3  {"question":[{"ques":"intro","ques_title":"","...          None
# 4  {"question":[{"ques":"intro","ques_title":"","...          None
#
#                   ques_ids  weightage  ... offer_status sr_id  main_sr_id  \
# ...

# %%
pre_recorded_kit_df.shape, ai_video_kit_df.shape
# Out:
# ((5852, 27), (52, 14))

# %%
# Group by catcher_id and sum answer_duration
ai_video_kit_df = ai_video_kit_df.groupby('catcher_id').size().reset_index(name='ai_kit_counts')

# %%
ai_video_kit_df
# Out:
#    catcher_id  ai_kit_counts
# 0        1873             32
# 1        6543              1
# 2        8565              4
# 3        8597              1
# 4        8873             10
# 5        9265              1
# 6        9299              1
# 7        9313              1
# 8        9443              1

# %%
ai_video_kit_df.nunique()
# Out:
# catcher_id       9
# ai_kit_counts    4
# dtype: int64

# %%
pre_recorded_kit_df = pre_recorded_kit_df.groupby('catcher_id').size().reset_index(name='pre_recorded_kit_counts')

# %%
pre_recorded_kit_df
# Out:
#       catcher_id  pre_recorded_kit_counts
# 0              0                       17
# 1              1                       96
# 2             92                        2
# 3            151                        1
# 4            207                        1
# ...          ...                      ...
# 1077        9413                        1
# 1078        9415                        1
# 1079        9433                        1
# 1080        9443                        1
# 1081        9579                        1
#
# [1082 rows x 2 columns]

# %%
pre_recorded_kit_df.nunique()
# Out:
# catcher_id                 1082
# pre_recorded_kit_counts      60
# dtype: int64

# %%
pre_recorded_kit_df.shape
# Out:
# (1082, 2)

# %%
pre_recorded_kit_df.max()
# Out:
# catcher_id                 9579
# pre_recorded_kit_counts     297
# dtype: int64

# %%
ai_video_kit_df.max()
# Out:
# catcher_id       9443
# ai_kit_counts      32
# dtype: int64

# %%
ai_video_kit_df.isna().sum()
# Out:
# catcher_id       0
# ai_kit_counts    0
# dtype: int64

# %%
pre_recorded_kit_df.isna().sum()
# Out:
# catcher_id                 0
# pre_recorded_kit_counts    0
# dtype: int64

# %%
pre_recorded_kit_df.to_csv("pre_recorded_kits_df.csv", index=False)

# %%
ai_video_kit_df.to_csv("ai_video_kits_df.csv", index=False)
