# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/test")

# %%
catcher_df = pd.read_sql("SELECT * FROM jobma_catcher where jobma_catcher_parent=0", con=engine)
# log_in_df=pd.read_sql("Select * FROM jobma_catcher", engine)
# wallet_df = pd.read_sql("Select * FROM wallet", engine) 
# subscription_df = pd.read_sql("Select * FROM subscription_history", engine)

# #kits created
# # ai_video_kit_df = pd.read_sql("SELECT * FROM ai_video_kit", engine)
# pre_recorded_kit_df = pd.read_sql("SELECT * FROM job_assessment_kit", engine)

# #job posted and invitation and pitchers
# job_posting_df = pd.read_sql("SELECT * FROM jobma_employer_job_posting", engine)
# invitation_df = pd.read_sql("Select * FROM jobma_pitcher_invitations", engine)
# pitchers_df = pd.read_sql("SELECT * FROM jobma_pitcher_applied_jobs", engine) 

# #candidate interview response data, #just for pre-recorded type, # live interview type
# pre_rec_interviews_df = pd.read_sql("SELECT * FROM jobma_interviews", engine) 
# live_interviews_df = pd.read_sql("SELECT * FROM jobma_interviews_online", engine)
# # ai_interviews_df = pd.read_sql("SELECT * FROM jobma_ai_interviews", engine)

# %%
#Fillin nan
def fill_missing_values(df):
    df = df.copy()
    for col in df.columns:
        if df[col].dtype.kind in ['i']:
            df[col] = df[col].fillna(0)
        elif df[col].dtype.kind in ['f']:
            df[col] = df[col].fillna(0.0)
        elif df[col].dtype == object:
            df[col] = df[col].fillna('others')
        else:
            df[col] = df[col].fillna(df[col].mode()[0])
    return df

# %%
#Catcher_df

# %%
catcher_df.shape
# Out:
# (4466, 69)

# %%
catcher_df.rename(columns={"jobma_catcher_id": "catcher_id"}, inplace=True)

# %%
catcher_df =catcher_df[['catcher_id',
                        'jobma_catcher_title',
                        'jobma_catcher_email',
                        'jobma_catcher_status',
                        'jobma_catcher_creation',
                        'jobma_catcher_type',
                        'is_premium',
                        'jobma_verified',
                        'subscription_status',
                        'sub_user',
                        'per_sub_user',
                        'subscription_type',
                        'currency',
                        'company_size',
                       ]].copy()

# %%
# Calculating days
catcher_df['jobma_catcher_creation'] = pd.to_datetime(catcher_df['jobma_catcher_creation'], errors='coerce')
catcher_df['days_since_creation'] = (pd.Timestamp('today') - catcher_df['jobma_catcher_creation']).dt.days

# %%
catcher_df['subscription_status'].unique()
# Out:
# array([1, 2, 0])

# %%
catcher_df['subscription_status'].value_counts(dropna=False)
# Out:
# subscription_status
# 2    3356
# 1    1106
# 0       4
# Name: count, dtype: int64

# %%
catcher_df['jobma_catcher_status'] = catcher_df['jobma_catcher_status'].replace('-1', 0), inplace=True
catcher_df['subscription_status'] = catcher_df['subscription_status'].replace('0', 1),inplace=True
catcher_df['jobma_catcher_status'] = catcher_df['jobma_catcher_status'].astype(int)
catcher_df['jobma_catcher_type'] = catcher_df['jobma_catcher_type'].astype(int)
catcher_df['jobma_verified'] = catcher_df['jobma_verified'].astype(int)
catcher_df['subscription_status'] = catcher_df['subscription_status'].astype(int)
# Out:
#   Cell In[33], line 1
#     catcher_df['jobma_catcher_status'] = catcher_df['jobma_catcher_status'].replace('-1', 0), inplace=True
#     ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
catcher_df['is_premium'] = catcher_df['is_premium'].replace('', 0)
catcher_df['is_premium'] = catcher_df['is_premium'].astype(int)

# %%
catcher_df['jobma_catcher_type'] = catcher_df['jobma_catcher_type'].fillna(0)

# %%
catcher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4466 entries, 0 to 4465
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   catcher_id              4466 non-null   int64
#  1   jobma_catcher_title     4466 non-null   int64
#  2   jobma_catcher_email     4466 non-null   object
#  3   jobma_catcher_status    4466 non-null   int64
#  4   jobma_catcher_creation  4466 non-null   datetime64[ns]
#  5   jobma_catcher_type      4466 non-null   int64
#  6   is_premium              4466 non-null   int64
#  7   jobma_verified          4466 non-null   int64
#  8   subscription_status     4466 non-null   object
#  9   sub_user                4466 non-null   int64
#  10  per_sub_user            4466 non-null   object
#  11  subscription_type       4466 non-null   object
#  12  currency                4466 non-null   object
#  13  company_size            4463 non-null   object
#  14  days_since_creation     4466 non-null   int64
# dtypes: datetime64[ns](1), int64(8), object(6)
# memory usage: 523.5+ KB
