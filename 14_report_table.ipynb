# %% [markdown]
# # Now Report table
# #different types of saved reports.

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
report_df = pd.read_sql("SELECT * FROM report", engine) #different types of saved reports.

# %%
report_df.T
# Out:
#                                                                        0   \
# id                                                                     43
# employer_id                                                          1873
# name                                                        Report_ED5B1N
# category                                                                1
# created_on                                                     2024-08-26
# file                                        Report_ED5B1N_2024-08-26.xlsx
# auto_report_status                                                      0
# auto_report_type                                                        0
# auto_report_type_value                                               None
# filter_status_json      {"subAcc": "NULL", "jobPostId": "NULL", "endDa...
# required_filter_column                                               None
# created_at                                            2024-08-26 11:33:44
# ...

# %%
report_selected_df=report_df[['id',
                              'employer_id',#4 , 1873--79, 8464--9, 9315--8, 6543--2
                              # 'name',#@58, names of reports
                              'category',#@4--, 1,3,,2,4--->1mostly
                              # 'created_on',
                              # 'file',#file name
                              'auto_report_status',#@2 0,1---->0
                              'auto_report_type',#@3,    0,2,1...>0
                              # 'auto_report_type_value', #@ None and dates
       
                              'filter_status_json',#@13, dict and status , invite, saubac,...
                              'required_filter_column',#@3, None,[1], [1,2], [1,2,3]---->None
                              
                              'created_at',
                              'updated_at',
                              'deleted_at']]
