# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
df = pd.read_sql("SELECT * FROM jobma_pitcher_applied_jobs", engine)

# %%
df = df.groupby('catcher_id').size().reset_index(name='number_of_pitchers_applied')

# %%
df.nunique()
# Out:
# catcher_id                    956
# number_of_pitchers_applied    126
# dtype: int64

# %%
df
# Out:
#      catcher_id  number_of_pitchers_applied
# 0           0.0                           1
# 1          92.0                       17640
# 2          96.0                           3
# 3          97.0                           2
# 4          99.0                          67
# ..          ...                         ...
# 951      9325.0                           2
# 952      9365.0                           5
# 953      9403.0                          10
# 954      9415.0                           4
# 955      9431.0                           1
#
# [956 rows x 2 columns]

# %%
df.to_csv("pitchers_applied_df.csv", index=False)
