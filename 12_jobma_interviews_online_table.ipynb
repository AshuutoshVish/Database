# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
#candidate interview response data (just for live interview type)
jobma_interviews_online_df = pd.read_sql("SELECT * FROM jobma_interviews_online", engine)

# %%
jobma_interviews_online_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1205 non-null   int64
#  1   invitation_id         1205 non-null   int64
#  2   jobma_applied_id      863 non-null    float64
#  3   jobma_pitcher_id      1205 non-null   int64
#  4   jobma_job_post_id     1205 non-null   int64
#  5   jobma_catcher_id      1205 non-null   int64
#  6   video_names           1205 non-null   object
#  7   source                1205 non-null   int64
#  8   quality_of_session    94 non-null     object
#  9   interview_status      1205 non-null   object
#  10  payment_status        1205 non-null   object
#  11  record                1205 non-null   int64
#  12  interview_rate        1205 non-null   float64
#  13  interview_credit      1205 non-null   float64
#  14  video_time            1205 non-null   object
# ...

# %%
jobma_interviews_online_df.T
# Out:
#                                      0                    1     \
# id                                      1                   16
# invitation_id                          41                  471
# jobma_applied_id                      NaN              40422.0
# jobma_pitcher_id                    39855                39176
# jobma_job_post_id                    4994                19079
# jobma_catcher_id                      446                  720
# video_names                                  /uploads/room-471
# source                                  0                    0
# quality_of_session                   None                 None
# interview_status                        1                    1
# payment_status                          1                    1
# record                                  0                    0
# interview_rate                        0.0                  0.0
# interview_credit                      0.0                  0.0
# video_time
# ...

# %%
jobma_interviews_online_selected_df=jobma_interviews_online_df[['id',
                                                                # 'invitation_id',
                                                                # 'jobma_applied_id',#@805
                                                                # 'jobma_pitcher_id',#@716
                                                                # 'jobma_job_post_id',
                                                                'jobma_catcher_id',###########@121-----------mostly 7151,924, 1873,1372
                                                                # 'video_names',
                                                                'source',#0,1------1
                                                                # 'quality_of_session',
                                                                'interview_status',#1,0-------------->almost all 1
                                                                # 'payment_status',#1,0-------------->almost all 1
                                                                # 'record',
                                                                'interview_rate',###@17       #1.0,0.0,4.0,1.5.....50.0__________thios the actual cost of interviw may be.........
                                                                # 'interview_credit',#@11   #1.0,0.0,4.0,1.5.....50.0
                                                                # 'video_time',
                                                                # 'view_date',
                                                                # 'subscription_type',#0,1---------->1
                                                                # 'interview_cost_type', #1 1....
                                                                # 'video_request_status',#0,1,2
                                                                # 'notes',#notess
                                                                # 'deleted_at',
                                                                # 'created_at',
                                                                # 'updated_at'
                                                               ]].copy()

# %%
 jobma_interviews_online_df.shape, jobma_interviews_online_selected_df.shape
# Out:
# ((1205, 23), (1205, 5))
