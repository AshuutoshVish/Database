# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
jobma_catcher_df = pd.read_sql("SELECT * FROM jobma.jobma_catcher where jobma_catcher_parent=0;", engine)
jobma_catcher_df.shape
# Out:
# (5546, 75)

# %%
jobma_catcher_df.rename(columns={'jobma_catcher_id': 'catcher_id'}, inplace=True)

# %%
catcher_df  = jobma_catcher_df[['catcher_id',
                                'jobma_catcher_title',
                                'jobma_catcher_otype',
                                'jobma_catcher_status',
                                'jobma_catcher_creation',
                                'jobma_catcher_type',
                                'is_premium',
                                'subscription_status',
                                'sub_user',
                                'per_sub_user',
                                'subscription_type',
                                'created_at',
                                'referral_credit',
                                'company_size',
                                'ai_live_interview',
                               ]].copy()
catcher_df
# Out:
#       catcher_id  jobma_catcher_title jobma_catcher_otype  \
# 0             92                    0                   1
# 1            106                    0
# 2            124                    0
# 3            125                    0
# 4            126                    0
# ...          ...                  ...                 ...
# 5541        9319                    4                   1
# 5542        9365                    0
# 5543        9405                    1                   1
# 5544        9413                    0
# 5545        9445                    1
#
#      jobma_catcher_status jobma_catcher_creation jobma_catcher_type  \
# 0                       1             2016-11-22                  1
# 1                      -1             2012-12-08                  0
# 2                       1             2013-11-15                  0
# 3                       1             2013-11-18                  0
# ...

# %%
catcher_df.nunique()
# Out:
# catcher_id                5546
# jobma_catcher_title          9
# jobma_catcher_otype          8
# jobma_catcher_status         3
# jobma_catcher_creation    1083
# jobma_catcher_type           2
# is_premium                   3
# subscription_status          3
# sub_user                    62
# per_sub_user                 9
# subscription_type            2
# created_at                5335
# referral_credit              6
# company_size                 5
# ai_live_interview            2
# dtype: int64

# %%
catcher_df['jobma_catcher_type'].value_counts()
# Out:
# jobma_catcher_type
# 1    4951
# 0     428
# Name: count, dtype: int64

# %%
catcher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5546 entries, 0 to 5545
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   catcher_id              5546 non-null   int64
#  1   jobma_catcher_title     5546 non-null   int64
#  2   jobma_catcher_otype     5546 non-null   object
#  3   jobma_catcher_status    5542 non-null   object
#  4   jobma_catcher_creation  5546 non-null   object
#  5   jobma_catcher_type      5379 non-null   object
#  6   is_premium              5546 non-null   object
#  7   subscription_status     5546 non-null   object
#  8   sub_user                5546 non-null   int64
#  9   per_sub_user            5546 non-null   object
#  10  subscription_type       5546 non-null   object
#  11  created_at              5546 non-null   datetime64[ns]
#  12  referral_credit         5546 non-null   int64
#  13  company_size            4491 non-null   object
# ...

# %%
catcher_df.describe(include='all')
# Out:
#          catcher_id  jobma_catcher_title jobma_catcher_otype  \
# count   5546.000000          5546.000000                5546
# unique          NaN                  NaN                   8
# top             NaN                  NaN
# freq            NaN                  NaN                5104
# mean    4766.986116             0.235485                 NaN
# min       92.000000             0.000000                 NaN
# 25%     2772.250000             0.000000                 NaN
# 50%     4791.500000             0.000000                 NaN
# 75%     6914.750000             0.000000                 NaN
# max     9445.000000             8.000000                 NaN
# std     2432.980364             0.777786                 NaN
#
#        jobma_catcher_status jobma_catcher_creation jobma_catcher_type  \
# count                  5542                   5546               5379
# unique                    3                   1083                  2
# ...

# %%
catcher_df.isna().sum()
# Out:
# catcher_id                   0
# jobma_catcher_title          0
# jobma_catcher_otype          0
# jobma_catcher_status         4
# jobma_catcher_creation       0
# jobma_catcher_type         167
# is_premium                   0
# subscription_status          0
# sub_user                     0
# per_sub_user                 0
# subscription_type            0
# created_at                   0
# referral_credit              0
# company_size              1055
# ai_live_interview            0
# dtype: int64

# %%
catcher_df['jobma_catcher_type'].value_counts(dropna=False)
# Out:
# jobma_catcher_type
# 1       4951
# 0        428
# None     167
# Name: count, dtype: int64

# %%
catcher_df['company_size'].value_counts(dropna=False)
# Out:
# company_size
# 1-25              1652
# 26-100            1476
# None              1055
# 101-500            891
# 500-1000           387
# More than 1000      85
# Name: count, dtype: int64

# %%
# Group-based fill: use the most common value of company_size within each subscription_status
catcher_df['company_size'] = catcher_df.groupby(['subscription_status', 'sub_user','is_premium'])['company_size']\
    .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else '1-25'))

# %%
catcher_df['company_size'].value_counts(dropna=False)
# Out:
# company_size
# 1-25              2648
# 26-100            1531
# 101-500            895
# 500-1000           387
# More than 1000      85
# Name: count, dtype: int64

# %%
catcher_df.isna().sum()
# Out:
# catcher_id                  0
# jobma_catcher_title         0
# jobma_catcher_otype         0
# jobma_catcher_status        4
# jobma_catcher_creation      0
# jobma_catcher_type        167
# is_premium                  0
# subscription_status         0
# sub_user                    0
# per_sub_user                0
# subscription_type           0
# created_at                  0
# referral_credit             0
# company_size                0
# ai_live_interview           0
# dtype: int64

# %%
catcher_df['jobma_catcher_type'].value_counts()
# Out:
# jobma_catcher_type
# 1    4951
# 0     428
# Name: count, dtype: int64

# %%
catcher_df['jobma_catcher_type'] = catcher_df.groupby(
    ['subscription_status', 'company_size', 'sub_user', 'is_premium'])['jobma_catcher_type'].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else '0'))

# %%
catcher_df['jobma_catcher_type'].value_counts()
# Out:
# jobma_catcher_type
# 1    5117
# 0     429
# Name: count, dtype: int64

# %%
# Calculating days
catcher_df['jobma_catcher_creation'] = pd.to_datetime(catcher_df['jobma_catcher_creation'], errors='coerce')
catcher_df['days_since_creation'] = (pd.Timestamp('today') - catcher_df['jobma_catcher_creation']).dt.days

# Handle NaT
catcher_df['days_since_creation'] = catcher_df['days_since_creation'].fillna(0)

# %%
sns.heatmap(catcher_df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
catcher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5546 entries, 0 to 5545
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   catcher_id              5546 non-null   int64
#  1   jobma_catcher_title     5546 non-null   int64
#  2   jobma_catcher_otype     5546 non-null   object
#  3   jobma_catcher_status    5542 non-null   object
#  4   jobma_catcher_creation  5364 non-null   datetime64[ns]
#  5   jobma_catcher_type      5546 non-null   object
#  6   is_premium              5546 non-null   object
#  7   subscription_status     5546 non-null   object
#  8   sub_user                5546 non-null   int64
#  9   per_sub_user            5546 non-null   object
#  10  subscription_type       5546 non-null   object
#  11  created_at              5546 non-null   datetime64[ns]
#  12  referral_credit         5546 non-null   int64
#  13  company_size            5546 non-null   object
# ...

# %%
catcher_df.isna().sum()
# Out:
# catcher_id                  0
# jobma_catcher_title         0
# jobma_catcher_otype         0
# jobma_catcher_status        4
# jobma_catcher_creation    182
# jobma_catcher_type          0
# is_premium                  0
# subscription_status         0
# sub_user                    0
# per_sub_user                0
# subscription_type           0
# created_at                  0
# referral_credit             0
# company_size                0
# ai_live_interview           0
# days_since_creation         0
# dtype: int64
