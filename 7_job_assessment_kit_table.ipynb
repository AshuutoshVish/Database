# %% [markdown]
# # job_assessment_kit_df
# #Kits created by employers for Pre-recorded interview which tell usage
# #May be Also Hold the information about how the interview gone and evaluation

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
job_assessment_kit_df = pd.read_sql("SELECT * FROM job_assessment_kit", engine)

# %%
job_assessment_kit_df.shape
# Out:
# (5852, 27)

# %%
job_assessment_kit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5852 entries, 0 to 5851
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5852 non-null   int64
#  1   catcher_id       5852 non-null   int64
#  2   title            5852 non-null   object
#  3   slug             5852 non-null   object
#  4   answer_duration  1181 non-null   float64
#  5   interview_type   5852 non-null   object
#  6   question_set     5852 non-null   object
#  7   pre_screening    63 non-null     object
#  8   ques_ids         5852 non-null   object
#  9   weightage        5852 non-null   int64
#  10  weightage_data   2 non-null      object
#  11  description      716 non-null    object
#  12  price            5852 non-null   int64
#  13  currency         5852 non-null   object
#  14  expiry           689 non-null    object
#  15  status           5852 non-null   int64
#  16  is_active        5852 non-null   int64
# ...

# %%
job_assessment_kit_df.describe().T
# Out:
#                   count                           mean                  min  \
# id               5852.0                  108254.587662                  3.0
# catcher_id       5852.0                    4376.385338                  0.0
# answer_duration  1181.0                 1818375.083827                  0.0
# weightage        5852.0                       0.000342                  0.0
# price            5852.0                       0.036569                  0.0
# status           5852.0                       0.999487                  0.0
# is_active        5852.0                       0.979494                  0.0
# main_sr_id       5852.0                       0.702837                  0.0
# created_at         5852  2021-06-23 22:35:16.385509376  2018-08-14 03:39:20
# updated_at         5852  2023-11-02 06:28:00.393028096  2023-10-05 04:52:21
#
#                                         25%                         50%  \
# ...

# %%
job_assessment_kit_df.isna().sum()
# Out:
# id                    0
# catcher_id            0
# title                 0
# slug                  0
# answer_duration    4671
# interview_type        0
# question_set          0
# pre_screening      5789
# ques_ids              0
# weightage             0
# weightage_data     5850
# description        5136
# price                 0
# currency              0
# expiry             5163
# status                0
# is_active             0
# offer_status       5823
# sr_id              5823
# main_sr_id            0
# node_id            5851
# random_ques           0
# random_options        0
# is_streaming          0
# deleted_at         5852
# created_at            0
# updated_at            0
# dtype: int64

# %%
job_assessment_kit_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
job_assessment_kit_df.isna().sum()
# Out:
# id                    0
# catcher_id            0
# title                 0
# slug                  0
# answer_duration    4671
# interview_type        0
# question_set          0
# pre_screening      5789
# ques_ids              0
# weightage             0
# weightage_data     5850
# description        5136
# price                 0
# currency              0
# expiry             5163
# status                0
# is_active             0
# offer_status       5823
# sr_id              5823
# main_sr_id            0
# node_id            5851
# random_ques           0
# random_options        0
# is_streaming          0
# deleted_at         5852
# created_at            0
# updated_at            0
# dtype: int64

# %%
# Check for duplicate count
print("No of duplicate catcher_id ----", job_assessment_kit_df['catcher_id'].duplicated().sum())

#top most duplicates
print("Top duplicated jobma_user_id ----")
print(job_assessment_kit_df['catcher_id'].value_counts().head(10))
# Out:
# No of duplicate catcher_id ---- 4770
# Top duplicated jobma_user_id ----
# catcher_id
# 1873    297
# 5943    196
# 2335    172
# 1839    151
# 5947    151
# 723     145
# 2169    131
# 5814    124
# 1371    106
# 6475     97
# Name: count, dtype: int64

# %%
column_data = job_assessment_kit_df['answer_duration']
print(job_assessment_kit_df.shape)
print("No of unique values----",column_data.nunique(dropna=False), "\n")
print("Unique values ---------",column_data.unique(), "\n")
print(column_data.value_counts(dropna=False).head(10), "\n")
print(job_assessment_kit_df['answer_duration'].head(10))
# Out:
# (5852, 27)
# No of unique values---- 47
#
# Unique values --------- [           nan 0.00000000e+00 2.00000000e+00 5.00000000e+01
#  5.00000000e+00 7.00000000e+00 6.00000000e+00 2.00000000e+01
#  1.00000000e+02 1.00000000e+00 1.20000000e+01 4.00000000e+00
#  3.00000000e+01 1.00000000e+01 1.50000000e+01 3.00000000e+00
#  2.34000000e+02 9.00000000e+00 2.10000000e+01 2.90000000e+01
#  2.20000000e+01 6.00000000e+01 9.00000000e+01 2.50000000e+01
#  4.00000000e+01 3.30000000e+01 2.14748365e+09 1.20000000e+02
#  8.00000000e+00 6.50000000e+01 1.80000000e+02 3.60000000e+03
#  3.20000000e+01 7.80000000e+01 6.30000000e+01 3.65500000e+03
#  5.60000000e+01 4.50000000e+01 2.30000000e+01 3.60000000e+01
#  3.70000000e+01 1.40000000e+01 1.70000000e+01 3.32000000e+02
#  1.11000000e+02 1.23000000e+02 1.21000000e+02]
#
# answer_duration
# NaN     4671
# 0.0      416
# 1.0      185
# 2.0      130
# 5.0      114
# 10.0      97
# 20.0      33
# 30.0      32
# 3.0       31
# 15.0      24
# ...

# %%
#These are the features And seting which the clients are using
job_assessment_kit_selected_df=job_assessment_kit_df[['id',
                                                      'catcher_id',
                                                      # 'title', #May be it may be title, intervie, test, system analyst, automation,
                                                      # 'slug', #slug, bash, test, people, react, testkit, checked, test-essay
                                                      'answer_duration', #how much time student takes to finish ----------------------------mostly nan-->>??
                                                      # 'interview_type',  #1, 2, 3, 4, Type of interview given live, ailive, video
                                                      # 'question_set', #Description about questions
                                                      # 'ques_ids', #Set of questions given to candidate #Can tell which type of candidate like tech non tech, finance etc
                                                      # 'pre_screening', #question given to candidates for prescreanings
                                                      # 'ques_ids', #
                                                      'weightage', #0,1-->0
                                                      # 'weightage_data', #mostly null
                                                      # 'description', #Dscription
                                                      'price', #0,100,10,3,1
                                                      'currency', #usd
                                                      'expiry', #expiration date mostly null
                                                      'status', #1,0-->1
                                                      'is_active', #1,0-->1
                                                      'offer_status', #active, inactive----mostly null
                                                      'sr_id', #ids mostly null--------------------------------------------------------------->
                                                      'main_sr_id', #mostly 0------------------------------------------------------------------>
                                                      # 'node_id', #mostly null
                                                      # 'random_ques', #_,0,1 mostly null
                                                      # 'random_options', #_,0,1 mostly null
                                                      # # 'is_streaming', #0,1
                                                      # 'deleted_at', #
                                                      # 'created_at',
                                                      # 'updated_at', #
                                                     ]].copy()

# %%
job_assessment_kit_df.shape, job_assessment_kit_selected_df.shape
# Out:
# ((5852, 27), (5852, 12))

# %%
job_assessment_kit_selected_df.describe().T
# Out:
#                   count          mean           std  min      25%     50%  \
# id               5852.0  1.082546e+05  2.432780e+05  3.0  2281.25  4394.5
# catcher_id       5852.0  4.376385e+03  2.700278e+03  0.0  1839.00  5441.5
# answer_duration  1181.0  1.818375e+06  6.248919e+07  0.0     0.00     1.0
# weightage        5852.0  3.417635e-04  1.848527e-02  0.0     0.00     0.0
# price            5852.0  3.656869e-02  1.853559e+00  0.0     0.00     0.0
# status           5852.0  9.994874e-01  2.263780e-02  0.0     1.00     1.0
# is_active        5852.0  9.794942e-01  1.417348e-01  0.0     1.00     1.0
# main_sr_id       5852.0  7.028366e-01  3.103642e+01  0.0     0.00     0.0
#
#                      75%           max
# id               6500.25  7.013890e+05
# catcher_id       6185.00  9.579000e+03
# answer_duration     5.00  2.147484e+09
# weightage           0.00  1.000000e+00
# price               0.00  1.000000e+02
# status              1.00  1.000000e+00
# ...

# %%
job_assessment_kit_selected_df.corr(numeric_only=True)
# Out:
#                        id  catcher_id  answer_duration  weightage     price  \
# id               1.000000    0.163284        -0.015532   0.045074 -0.008538
# catcher_id       0.163284    1.000000         0.017016  -0.017143 -0.031980
# answer_duration -0.015532    0.017016         1.000000        NaN       NaN
# weightage        0.045074   -0.017143              NaN   1.000000 -0.000365
# price           -0.008538   -0.031980              NaN  -0.000365  1.000000
# status           0.009846    0.017702              NaN   0.000419  0.000447
# is_active       -0.060928    0.001599         0.005380   0.002675  0.002855
# main_sr_id      -0.009974   -0.025200              NaN  -0.000419 -0.000447
#
#                    status  is_active  main_sr_id
# id               0.009846  -0.060928   -0.009974
# catcher_id       0.017702   0.001599   -0.025200
# answer_duration       NaN   0.005380         NaN
# weightage        0.000419   0.002675   -0.000419
# ...

# %%
#Heatmap
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(job_assessment_kit_selected_df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=16)
plt.show()
