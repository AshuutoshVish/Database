# %% [markdown]
# # Combining Tables

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
#Client details 
jobma_catcher_df = pd.read_sql("SELECT * FROM jobma_catcher", engine) 

# tanure, Usage
jobma_login_df = pd.read_sql("SELECT * FROM jobma_login", engine) #Usage details-------------How many times he logins__we willl take only value _counts 
jobma_wallet_df = pd.read_sql("SELECT * FROM wallet", engine) #How aggresively using + how much #account Wallet info
jobma_subscription_history_df = pd.read_sql("SELECT * FROM subscription_history", engine) #how much frequently using #subscription history

#kits created and used by client - Features used by client
default_assessment_kits_df = pd.read_sql("SELECT * FROM default_assessment_kits", engine) 
job_assessment_kit_df = pd.read_sql("SELECT * FROM job_assessment_kit", engine)
ai_video_kit_df = pd.read_sql("SELECT * FROM ai_video_kit", engine) 

#Candidate details and how many jobs he is posting may as we have invitation column also----------------?????
jobma_pitcher_applied_jobs_df = pd.read_sql("SELECT * FROM jobma_pitcher_applied_jobs", engine)
jobma_employer_job_posting_df = pd.read_sql("SELECT * FROM jobma_employer_job_posting", engine)
jobma_pitcher_invitations_df = pd.read_sql("SELECT * FROM jobma_pitcher_invitations", engine)
print("All tables data downloaded...!!")

# %%
#===========================================================Client catcher table df

# %%
jobma_catcher_selected_df= jobma_catcher_df[['jobma_catcher_id',
                                             # 'jobma_catcher_fname',#Name of client
                                             # 'jobma_catcher_lname',#Last name of client
                                             # 'jobma_catcher_dob',#Birthdate------> How old the client is
                                             # 'jobma_catcher_video_status',#@3, 1, 0  mostly None
                                             'jobma_catcher_company',#@1890       #About compny[ssi, jobma, golden compass, uk aviation]
                                             # 'org_type', #@9       #1,2, employer, recruiter, php, corporation......................................??
                                             # 'sec_ques_id',#@4    #values are 0,1,2,3----->0......................???
                                             # 'security_ans',#@4    #Ans
                                             # 'jobma_about_company',      #About company or company introduction
                                             'jobma_functional',      #IT, HR, Airlines, Supply, accounting, sales------------>??
                                             'jobma_catcher_indus', #342  #mostly id, software, it, 
                                             # 'jobma_company_email',#@1529  #email id of company
                                             # 'jobma_catcher_email',#email id of company
                                             'jobma_catcher_title', #@9     #0,1,2......8-------------------???
                                             'jobma_catcher_ext',     #123,357,789,1234......................>>??
                                             'jobma_catcher_otype',    #1,2,Employer,recruiting firm,ad agency, 101,18
                                             # 'jobma_catcher_photo', #
                                             # 'jobma_catcher_logo', #logo url
                                             # 'jobma_catcher_website',#company website url
                                             # 'jobma_company_address',#company address
                                             # 'jobma_catcher_address2',#address2
                                             # 'jobma_catcher_video',#video link
                                             # 'jobma_catcher_city',     #numeric coded vlaue
                                             # 'jobma_catcher_state',#Numeric coded value............
                                             # 'jobma_catcher_country',#country code or name
                                             # 'jobma_catcher_zip',#zip code
                                             # 'jobma_catcher_fax',#fax number
                                             # 'jobma_catcher_phone',#phone number
                                             'jobma_catcher_status',#0,1-------------------------------------->???
                                             'jobma_catcher_creation',#date---------------------------------------------------Mya be used to find how old on jobmaa?????
                                             'jobma_catcher_type',  #0,1--------------------------------------->
                                             'jobma_catcher_sub_accounts',#0,_,7,49----------------------------->
                                             'is_premium',#0,1
                                             'jobma_catcher_parent',#0.92,1873,1692------------------------------>
                                             'jobma_catcher_is_deleted',#0,1 #date---------------------------------------------------Mya be used to find how old on jobmaa?????
                                             'jobma_verified',#0,1 Mostly 
                                             'jobma_in_index',#mostly 1,     
                                             # 'data_access',#mostly 1,     
                                             'subscription_status',#1,2,3---------------------------------------->     
                                             # 'interview_rate',#0.0------------------------------------------------->want to use but (0.0) values only
                                             # 'remember_token',#token key
                                             # 'deleted_at',#deletion date
                                             # 'api_key',#api key
                                             'sub_user',#0,1,2,10,999,----------------------------->
                                             'per_sub_user',#10,10000,60,[60,100]
                                             'live_interview_credit',#0.0,1.0,1.5,15
                                             # 'pre_recorded_credit',#0.0,1.0,1.5,2.0,15
                                             # 'ai_live_interview_credit',#1.0,2.0  mostly 1
                                             # 'credit_value',#1,2,4,5,8 mostly 1
                                             # 'interview_cost_type',#0,1
                                             'subscription_type',#0,1
                                             # 'phone_call_cost_type',
                                             # 'call_and_regording_credits',#1,2,5,9999,111---------------------------------->>Mostly null
                                             # 'transcription_credits',##1,2,5,9999,111------------------------------------------>>Mostly Null
                                             # 'temp_subscription_type',#temporary subscription
                                             # 'created_at',#creation date
                                             # 'updated_at',#updation date
                                             # 'jobma_support_rtc',#0,1,2---------------------------------??whattt
                                             # 'interview_question',#3,4,5,10,20--------------------->>
                                             # 'video_recording_suppport',#0,1,2
                                             'subaccount_permission',#
                                             # 'reply_email',#reply mail id
                                             # 'sing_up_canditate_after_apply',#0,1 mostly 0
                                             'currency',#0,1---------------------------------->1 for usd
                                             'referral_credit',#0,100,200,400 mostky 0------------->>>
                                             'company_size',#1-25, 26-100, 101-500, 500-1000, morethan 1000         #########used
                                             # 'theme',#0,1----------------------------------------faeture
                                             # 'flag',#0,1,2---------------------------------------------------------------...????
                                             # 'jobma_auto_recording_status',#0,1 mostly 0
                                             # 'jobma_scenario_question_status',#0,1 mostly 0
                                             'ai_live_interview',#0,1---0
                                             # 'ms_teams_chat_reference',#ms teams chat link
                                             # 'bot_audio',#0,1-=-->1
                                             'approval',#only 0
                                            ]]

# %%
#=================================================================jobma_login_df

# %%
jobma_login_selected_df=jobma_login_df[['jobma_login_id',        #@39321 id
                                    # 'jobma_user_name',       # name
                                    # 'jobma_password',        # password
                                    # 'jobma_role_id',         #@7, 4,3,5,0,9,1,2 id----------------------------->>
                                    'jobma_user_id',         # id
                                    'jobma_last_login',      #@18233 almost 0000.000, None--------------------->> 
                                    'jobma_created_by',      #@4, NOne, 1, 0, 2-------------------------------->>
                                    'confirmed',             # 0,1-----1
                                    # 'confirmation_code',     #mostly null and email...
                                    'jobma_login_status',    #@4  -,0,1----------------------------------------->>
                                    # 'jobma_login_ip',        
                                    # 'forget_password',       
                                    # 'remember_token',        
                                    # 'jobma_social_login',    #2,  0,1---->0
                                    # 'password_changed_at',   
                                    'deleted_at',            #39237 is NAt value----------------------------------------------->>required all below three columns to know tenure of client
                                    'created_at',            ##---------------------------------------------------------------->> to find user tenure
                                    # 'updated_at',            ##----------------------------------------------------------------->>
                                    # 'google2fa_secret',      
                                    # 'two_factor_status',     #@0,1----->0
                                    # 'two_factor_type'        #@0,1----->0
                                   ]].copy()

# %%
#============================================================================jobma_wallet_selected_df

# %%
jobma_wallet_selected_df = jobma_wallet_df[['catcher_id',   #@5560
                                            # 'id',
                                            'credit_amount',#@40,  Nan, -------------------------------------------->>??Required
                                            'wallet_amount', #amounts or balance may be ---------------------------->>??
                                            'subscription_type', #0,1    mostly------------------------->> 0
                                            'plan_type',#0,1
                                            'is_unlimited',#0, 1------------------------------------------------------>>
                                            'premium_storage',#------------------------------------------------------->>All are 0
                                            'trial_account_type',#0.0,1.0--------------------------------------------->>mostly zero   #can be used to remove and fill values
                                            # 'gst_code',#
                                            # 'billing_cycle', #not relevantdat
                                            'billing_cycle_status',#0,1 may be koi relation ho plan se ya user type se
                                            'created_at',# there may be many created and updated column--------------->> can be considered use as client age with us
                                            'updated_at'
                                         ]].copy()

# %% [markdown]
# #jobma_subscription_history_selected_df

# %%
jobma_subscription_history_selected_df = jobma_subscription_history_df[['catcher_id',  # duplicated catcher id as has buy many times
                                                                        # 'id',  # starts from 2
                                                                        # 'catcher_username', 
                                                                        # 'catcher_email', 
                                                                        'sub_user_id',  #@407 unique values,  sub users and admins too many with same id----------------->>
                                                                        'subscription_id',  # 1,2------------------------------------------------------------------------>>
                                                                        'premium_plan_id',  #@10    1.0,2.0,3.0....10.0------------------------------------>>3.0,2.0 mostly
                                                                        'premium_plan',  #@802 unique but dict------------ category of different different plans............??
                                                                        # 'transaction_id',
                                                                        'subscription_amount',  # diffrenet may be taken bu client--plan prices ----->May be................??
                                                                        'credit_given',  #@37,   0,50,600,.................................How much credits they got on buying
                                                                        # 'paypal_profile_id',
                                                                        # 'paypal_payer_id',
                                                                        'expiry_date',
                                                                        'currency',  # 0,1-------------------------------------------------------------meaning of 0 ,1--------??
                                                                        # 'premium_storage',----------------------------------------------------------all are 0...............??
                                                                        # 'igst',
                                                                        # 'cgst',
                                                                        # 'gst_code',
                                                                        'currency_val',  #@39,   1, 70 mostly 1 and 70-------------------------------------------------------->>
                                                                        # 'recurring_data',  # Categorial data #Text data
                                                                        'payment_mode',#@7, unique['1' '2' '3' '5' '' '6' '4'] , mostly 1,6,3
                                                                        'status',  #1,0 iska nahi pta hai---------------------------------------------------------------------->>
                                                                        'payment_status',#1,0-----------------------------------------------------------------------mostly 1--->>
                                                                        # 'e_invoice',
                                                                        # 'cheque_number',
                                                                        # 'banker',
                                                                        # 'cheque_amount',
                                                                        # 'cheque_image',
                                                                        # 'cancel_date',
                                                                        # 'invoice_suffix',
                                                                        # 'radioGstValue',
                                                                        # 'created_at',
                                                                        # 'updated_at'
                                                                       ]].copy()

# %% [markdown]
# # default_assessment_kits_df

# %%
default_assessment_kits_df.columns
# Out:
# Index(['id', 'kit_name', 'interview_type', 'interview_category', 'category_id',
#        'sub_category_id', 'kit_description', 'question_set', 'ques_ids',
#        'industry_id', 'status', 'created_at', 'updated_at'],
#       dtype='object')

# %%
#These are the features And seting which the clients are using
default_assessment_kits_selected_df=default_assessment_kits_df[['id',
                                                                'kit_name',#may be question set  from data science, testing, sw et
                                                                'interview_type', #0
                                                                'interview_category', #category of interview ,1,2,3,4,5,-->0
                                                                'category_id', #lot of category id 15,17,56,57,77,177
                                                                'sub_category_id',  #float values 1.0,2.0,4.0,12.0......
                                                                'kit_description', #Description about questions
                                                                'ques_ids', #ids of questions
                                                                'industry_id', #industry id 1,23,28,14,... from which type of industry belong these questions
                                                                'status', #1
                                                                'created_at',
                                                                'updated_at'
                                                               ]].copy()

# %% [markdown]
# # job_assessment_kit_df

# %%
#These are the features And seting which the clients are using
job_assessment_kit_selected_df=job_assessment_kit_df[['id',
                                                      'catcher_id',
                                                      # 'title', #May be it may be title, intervie, test, system analyst, automation,
                                                      # 'slug', #slug, bash, test, people, react, testkit, checked, test-essay
                                                      'answer_duration', #how much time student takes to finish ----------------------------mostly nan-->>??
                                                      # 'interview_type',  #1, 2, 3, 4, Type of interview given live, ailive, video
                                                      # 'question_set', #Description about questions
                                                      # 'ques_ids', #Set of questions given to candidate #Can tell which type of candidate like tech non tech, finance etc
                                                      # 'pre_screening', #question given to candidates for prescreanings
                                                      # 'ques_ids', #
                                                      'weightage', #0,1-->0
                                                      # 'weightage_data', #mostly null
                                                      # 'description', #Dscription
                                                      'price', #0,100,10,3,1
                                                      'currency', #usd
                                                      'expiry', #expiration date mostly null
                                                      'status', #1,0-->1
                                                      'is_active', #1,0-->1
                                                      'offer_status', #active, inactive----mostly null
                                                      'sr_id', #ids mostly null--------------------------------------------------------------->
                                                      'main_sr_id', #mostly 0------------------------------------------------------------------>
                                                      # 'node_id', #mostly null
                                                      # 'random_ques', #_,0,1 mostly null
                                                      # 'random_options', #_,0,1 mostly null
                                                      # # 'is_streaming', #0,1
                                                      # 'deleted_at', #
                                                      # 'created_at',
                                                      # 'updated_at', #
                                                     ]].copy()

# %% [markdown]
# # ai_video_kit_df

# %%
ai_video_kit_selected_df = ai_video_kit_df[['id', #starts from 13
                                            'catcher_id',
                                            # 'title',#react, kit, python, javascript
                                            # 'slug',#jquery, react
                                            'answer_duration',#time taken to answer
                                            # 'question_set',
                                            # 'min_experience',#Experience of candidate -------------------may be used later on candidate related task-----??@@
                                            # 'max_experience',#............................................??@@
                                            'interview_level',#2,3,1 .............................................??@@
                                            # 'evaluation_keywords',#["Coding Skills"],["Python", "Jquery", "Laravel"]
                                            'is_active',#,
                                            # 'deleted_at',#Null
                                            # 'created_at',
                                            # 'updated_at'
                                           ]].copy()

# %% [markdown]
# # jobma_pitcher_applied_jobs_selected_df

# %%
jobma_pitcher_applied_jobs_selected_df = jobma_pitcher_applied_jobs_df[['jobma_applied_id', #starts from 13
                                                                        'jobma_pitcher_id',#59540,59631,59775 likee
                                                                        'jobma_post_id',#0,763,759,770,771
                                                                        'catcher_id',#--------------------------------->> problem in catcher_id as in the workbench it is in but now in int as forcely changed
                                                                        # 'jobma_applied_date',#
                                                                        # 'jobma_contacted_date',#
                                                                        # 'jobma_contacted_text',#
                                                                        'status',#0,1,2,3,4---------->
                                                                        # 'tags',#test,arp,good,php,java
                                                                        # 'jobma_assessment_id',#float values  118.0,147.0,148.8.... mostly 0
                                                                        'invitation_id',#ids, mostly 0
                                                                        # 'documents',#mostly null or stringresums, summary
                                                                        #'status_name',#Null
                                                                        # 'pre_recorded_payment_status',#0,1 mostly 0
                                                                        'live_interview_payment_status',#0,1 mostly 0
                                                                        'apply_mode',#0,1,2,3,4,5,6 mostly
                                                                        'jobma_interview_rounds',#0,1,2,3,4
                                                                        # 'avg_ai_score',#Score generated by the AI found in only 15 tables
                                                                        # 'pre_screen_qualify',#0,1,2
                                                                        # 'integration_source',#one value in one colum
                                                                        # 'source',#jobma,microsoft teams,ZOom mostly jobma
                                                                        # 'export',#0,1 almost all are 0
                                                                        # 'deleted_rounds',####Problem  may be ticket raise
                                                                        # 'deleted_at',#
                                                                        # 'created_at',#
                                                                        # 'updated_at'
                                                                       ]].copy()

# %% [markdown]
# # jobma_employer_job_posting

# %%
jobma_employer_job_posting_selected_df = jobma_employer_job_posting_df[['jobma_job_post_id',
                                                                        'taleo_job_id', #196 unique id
                                                                        'jobma_catcher_id', ############1292 unique values in it
                                                                        # 'job_assessment_kit_id',#
                                                                        # 'ai_live_kit_id', #Mostly null 0.0,17.0,1698.0.... @6
                                                                        # 'jobma_job_title', #Job titles as new job, job by position,timed,new,
                                                                        # 'slug',#######sameas title but more
                                                                        # 'jobma_job_description', #May be job descriptions
                                                                        # 'jobma_job_notes', #notes adding for candidate @27
                                                                        # 'jobma_job_type',#@14, contract,permanent,part time, intern
   
                                                                        # 'job_dur_year', #@12, 0.0,1.0...16
                                                                        # # # 'job_dur_month', 
                                                                        # # 'jobma_job_min_exp',########minimum experience may be used for prescreening or min exp
                                                                        # 'jobma_job_max_exp', ######max experience null,0.0.....
                                                                        # 'jobma_job_min_salary', #####salary offeredn or candidate salary

   
                                                                        # 'ai_rating_params',
                                                                        # 'jobma_job_sal_negotiable', #nan, 0.0,1 @2
                                                                        # 'jobma_job_sal_comments',#rate of sala pay mostly none
                                                                        # 'jobma_job_qualification', #952 value can be minimized
                                                                        # 'jobma_job_locations', #job location may be offered
                                                                        # 'jobma_job_industry',#it, medical, telecommunication..... categorial data
   
                                                                        # 'jobma_job_functional_areas', #it, eng, biotech etc
                                                                        # 'jobma_job_keywords',#keywords, pega, analyst, java, development
   
                                                                        # 'jobma_job_currency',#@12, usd, inr, 1,2,3,4 mostly null
                                                                        # 'jobma_job_salary_type',#annual, monthly, hourly, weekly
   
                                                                        'jobma_job_recruiter_name', #who recruited.......................>>mostly ssi, ssi
                                                                        #'jobma_job_recruiter_email',
   
                                                                        #'jobma_job_recruiter_phone', 
                                                                        'jobma_job_recruiter_ext',#some categorial code 7895,2656 like
   
                                                                        # 'jobma_job_recruiter_website', 
                                                                        # 'jobma_job_company_name',
   
                                                                        # 'jobma_job_company_profile', #intro of cmpy
                                                                        # 'jobma_job_company_website',
   
                                                                        # 'jobma_job_company_url_redirect', 
                                                                        # 'jobma_job_notice_period',#may be used when while reccomendind candidates in future, 0,3,2,4,1,5-->0
   
                                                                        # 'jobma_job_expiry_date', 
                                                                        # 'jobma_job_apply_count',#required but nullllll..............................................................>>???
   
                                                                        # 'jobma_job_view_count', #required but nullllll..............................................................>>???
                                                                        # 'jobma_job_inactive_date',#date for job inactivity
   
                                                                        # 'jobma_job_inactive_reason', #reason for inactivity mostly none, test, ok...
                                                                        # 'jobma_job_company_show',#0
   
                                                                        # 'jobma_job_recruiter_show', #0
                                                                        # 'jobma_job_interview_questions_ids',
   
                                                                        # 'jobma_question_think_time', 
                                                                        # 'jobma_question_takes',#can be used in recommender
   
                                                                        # 'jobma_job_interview_questions_durations', #can be used in recommender 
                                                                        # 'jobma_job_video_link',#none, yt_link ....
   
                                                                        # 'jobma_job_video_status', #1, None, null
                                                                        # 'video_flag', #Can be used in recommender, 0,1,2--->
                                                                        # 'jobma_job_status',#0,1-->0
   
                                                                        # 'jobma_job_filename', #none
                                                                        'approval', #1,0,2
                                                                        # 'jobma_job_paper_ids',#mostly none@31
   
                                                                        # 'optional_ques', #0
                                                                        # 'optional_ques_text', #none
                                                                        # 'job_subscription_status',#1
   
                                                                        # 'won_source_job_id', #None, 43-9061,51-1011... 
                                                                        # 'won_profile_name', #None, officeclerk,general.......................................................................>>>>??
                                                                        # 'won_job_status',  #none, 1 mostly none
   
                                                                        'applicant_count', #nan,0.0,32__mostly nuull_______________________________________________________________________________??
                                                                        # 'is_deleted', #nan, 0.0
                                                                        # 'is_hot', #0.0, nan, 1.0
                                                                        # 'source', #0,1 @2
                                                                        # 'source_id',  #@40, idss
   
                                                                        'is_private_job', #0,1, @3
                                                                        # 'google_schema',   #, _, 1,   #@2
                                                                        # 'monster_post_id', #None, @17
                                                                        # 'bamboo_job_id',#0
                                                                  
                                                                        # 'created_at', 
                                                                        # 'updated_at', 
                                                                        # 'jobma_job_created_date'  #Job creation  date by client
                                                                       ]].copy()

# %% [markdown]
# # jobma_pitcher_invitations_selected_df

# %%
jobma_pitcher_invitations_selected_df=jobma_pitcher_invitations_df[['id', 
                                                                  # 'jobma_post_id', 
                                                                  'jobma_catcher_id', #@1018
                                                                  # 'jobma_pitcher_id', #@33197
                                                                  # 'applied_id', #@18519
                                                                  
                                                                  # 'is_invited', #1,2,-
                                                                  # 'jobma_pitcher_email',
                                                                  # 'jobma_invitation_date', 
                                                                  # 'jobma_invitation_expire_date',
       
                                                                  # 'interview_start_time', #Usage time-------------######------------------Interaction with candidate
                                                                  # 'interview_end_time', #Usage time---------------######----------------Interaction with candidate
                                                                  # 'invitation_timezone',#asia,colombo
       
                                                                  # 'jobma_invitation_message', 
                                                                  'jobma_interview_round', #nan, 1.0 2.0.....8#################----------------------------------------------------------------??
                                                                  'stages',############0,1,2,3-------------------------------------------------------------------------------------------------??
       
                                                                  # 'jobma_interview_mode', #1,2,3,4,0------------------------
                                                                  # 'jobma_interview_room', #0
                                                                  # 'jobma_interview_token',#tokens mostly none
       
                                                                  # 'pre_recorded_token', #-, None
                                                                  # 'jobma_interview_status', ############3,2,4,0,1,6,5,- @8
                                                                  # 'assessment_kit_id',#idd
       
                                                                  # 'assessment_question_set', #question set used as intro, jr python developer @9806 object value
                                                                  # 'pre_screening', #@83 Questionss
                                                                  # 'pre_screen_qualify',#1,0,2
       
                                                                  # 'application_settings', ###############@2415 Settings turned on by client is important feature#########
                                                                  # 'practice_question', 
                                                                  # 'interview_type',#@5,          ###1,2,3,4,----------->>
       
                                                                  # 'answer_duration', #####################answer duration for interaction of client how much time client spends and about candidate knowledge
                                                                  # 'interview_time_lapse',######@0325   0,60,10,,20,120,
       
                                                                  # 'interview_complete_notified_email', #eamil to confirm
                                                                  # 'jobseeker_signup_confirmation', #0,1-->0
       
                                                                  # 'signup_form_options', #lot of value
                                                                  # 'can_request_retake', #@2   0,1
                                                                  'active', #0,1
       
                                                                  # 'prerecorded_email_notification', #email notifications
                                                                  # 'br_id', ###@34, 0.0, 58.0, 74.0
                                                                  'integration_source', #1
       
                                                                  # 'callback_url', #url giving to callback
                                                                  'acceptation', ######################3,1,2 mostly 3
                                                                  'reject_reason',#####################None, 1, 2
       
                                                                  # 'auto_send_reminder_max', #####@6        0,1,3,2,9,22
                                                                  # 'interview_platform_status', #####@2   0,1
                                                                  # 'source',#########@4,    None,0,2,1
       
                                                                  'live_interview_source', #None, 0, 1---->None
                                                                  # 'live_interview_data',###################@88   dictionary
                                                                  
                                                                  # 'deleted_at',
                                                                  # 'created_at', 
                                                                  # 'updated_at'
                                                                   ]].copy()

# %% [markdown]
# # jobma_interviews

# %%
jobma_interviews_selected_df=jobma_interviews_df[['id',#@21999
                                                  'jobma_post_id',#@3916
                                                  # 'jobma_pitcher_id',#@15360
                                                  'jobma_catcher_id',#@865
                                                  # 'interview_applied_id', #@19057
                                                  # 'jobma_invitation_id', #@19044
                                                  # 'jobma_interview_question_id',#1 

                                                  
                                                  # 'jobma_answers',# @19621 dict of question ans
                                                  # 'jobma_video_answer',#@1 none,-

                                                  # 'retake_requested', #@2 0,1-->0
                                                  # 'payment_status', #@2 1,0--->1
                                                  'interview_rate',######################@81 0.0,1.0,2.0,3.0,4.0,....10.0............>>

                                                  'interview_credit',#@58  0.0,1.0,....10.0 ----->1.0
                                                  # 'view_date', ###################################
                                                  # 'subscription_type',#@3 0,1,_, ---->0

                                                  # 'interview_cost_type', #@2 0,1
                                                  'evaluated_by', #@684 who evaluated the candidate may be ,,,, 0.0,Nan, 7151, 2335,...
                                                  # 'is_streaming', #@4   1,3,0,2---->1
                                                  
                                                  # 'deleted_at',
                                                  # 'created_at', 
                                                  # 'updated_at'
                                                 ]].copy()

# %% [markdown]
# # jobma_interviews_online

# %%
jobma_interviews_online_selected_df=jobma_interviews_online_df[['id',
                                                                # 'invitation_id',
                                                                # 'jobma_applied_id',#@805
                                                                # 'jobma_pitcher_id',#@716
                                                                # 'jobma_job_post_id',
                                                                'jobma_catcher_id',###########@121-----------mostly 7151,924, 1873,1372
                                                                # 'video_names',
                                                                'source',#0,1------1
                                                                # 'quality_of_session',
                                                                'interview_status',#1,0-------------->almost all 1
                                                                # 'payment_status',#1,0-------------->almost all 1
                                                                # 'record',
                                                                'interview_rate',###@17       #1.0,0.0,4.0,1.5.....50.0__________thios the actual cost of interviw may be.........
                                                                # 'interview_credit',#@11   #1.0,0.0,4.0,1.5.....50.0
                                                                # 'video_time',
                                                                # 'view_date',
                                                                # 'subscription_type',#0,1---------->1
                                                                # 'interview_cost_type', #1 1....
                                                                # 'video_request_status',#0,1,2
                                                                # 'notes',#notess
                                                                # 'deleted_at',
                                                                # 'created_at',
                                                                # 'updated_at'
                                                               ]].copy()

# %% [markdown]
# # jobma_ai_interviews

# %%
jobma_ai_interviews_selected_df=jobma_ai_interviews_df[['id',
                                                        # 'jobma_post_id',#@8 
                                                        # 'jobma_pitcher_id', #@66 #33421--49, 34089--13, 
                                                        'jobma_catcher_id',#@3,  64827-3, 64811-2....
       
                                                        # 'interview_applied_id',#@68, 64827--3, 648112 
                                                        'jobma_invitation_id',#@73 575621-2, 574473--1
                                                        # 'jobma_answers', #@72 Video answers, evaluations dictionary
       
                                                        # 'payment_status', #@2 1,0
                                                        'interview_rate',#@3,  1.0, 0.0, 2.0...............>>??
                                                        'interview_credit',#@2   1.0, Nan, 2.0
                                                        # 'view_date',#date when does it view or evaluated
       
                                                        'subscription_type',#@1  0 in all
                                                        'interview_cost_type',#@1  0 in all
                                                        'cron_status',#@3   1,2,0-->1,2
                                                        # 'deleted_at',
       
                                                        # 'created_at',
                                                        # 'updated_at'
                                                       ]]

# %% [markdown]
# # Working on required Dfs

# %%
jobma_catcher_selected_df

jobma_login_selected_df
jobma_wallet_selected_df
jobma_subscription_history_selected_df

default_assessment_kits_selected_df
job_assessment_kit_selected_df
ai_video_kit_selected_df

jobma_pitcher_applied_jobs_selected_df
jobma_employer_job_posting_selected_df
jobma_pitcher_invitations_selected_df

jobma_interviews_selected_df
jobma_interviews_online_selected_df
jobma_ai_interviews_selected_df
# Out:
#                                                                          0     \
# jobma_catcher_id                                                            1
# jobma_catcher_company                                                   Jobma
# sec_ques_id                                                                 0
# jobma_functional
# jobma_catcher_title                                                         0
# jobma_catcher_ext
# jobma_catcher_otype
# jobma_catcher_status                                                        0
# jobma_catcher_type                                                       None
# jobma_catcher_sub_accounts                                                  0
# is_premium                                                                  0
# jobma_catcher_parent                                                     8464
# jobma_verified                                                              1
# ...
