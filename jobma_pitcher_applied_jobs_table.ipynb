# %% [markdown]
# # jobma_pitcher_applied_jobs Table
# #How many jobs he is posting #Pitcher/Candidate details and status.
# #Candidate details and status
# #Float Value in catcher id

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
jobma_pitcher_applied_jobs_df = pd.read_sql("SELECT * FROM jobma_pitcher_applied_jobs", engine)

# %%
jobma_pitcher_applied_jobs_df
# Out:
#    jobma_applied_id  jobma_pitcher_id  jobma_post_id  catcher_id  \
# 0               154             77463          34345         0.0
# 1               155                 1            145        92.0
# 2               156               355            145        92.0
# 3               157               354            145        92.0
# 4               158               356            145        92.0
#
#     jobma_applied_date jobma_contacted_date jobma_contacted_text status  tags  \
# 0  2012-06-29 00:00:00           0000-00-00                           0
# 1  2012-07-19 00:00:00           0000-00-00                           3
# 2  2012-07-19 00:00:00           0000-00-00              slected      2  arp,
# 3  2012-07-19 00:00:00           0000-00-00                           3  arp,
# 4  2012-07-19 00:00:00           0000-00-00                           3
#
#    jobma_assessment_id  ...  avg_ai_score stages_status pre_screen_qualify  \
# ...

# %%
jobma_pitcher_applied_jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54961 entries, 0 to 54960
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   jobma_applied_id               54961 non-null  int64
#  1   jobma_pitcher_id               54961 non-null  int64
#  2   jobma_post_id                  54961 non-null  int64
#  3   catcher_id                     54345 non-null  float64
#  4   jobma_applied_date             54961 non-null  object
#  5   jobma_contacted_date           54961 non-null  object
#  6   jobma_contacted_text           54961 non-null  object
#  7   status                         54934 non-null  object
#  8   tags                           54961 non-null  object
#  9   jobma_assessment_id            34215 non-null  float64
#  10  invitation_id                  54961 non-null  int64
#  11  documents                      9341 non-null   object
# ...

# %%
jobma_pitcher_applied_jobs_df.isna().sum()
# Out:
# jobma_applied_id                     0
# jobma_pitcher_id                     0
# jobma_post_id                        0
# catcher_id                         616
# jobma_applied_date                   0
# jobma_contacted_date                 0
# jobma_contacted_text                 0
# status                              27
# tags                                 0
# jobma_assessment_id              20746
# invitation_id                        0
# documents                        45620
# status_name                          0
# pre_recorded_payment_status          0
# live_interview_payment_status        0
# apply_mode                           0
# jobma_interview_rounds             131
# avg_ai_score                     54933
# stages_status                        0
# pre_screen_qualify               54553
# integration_source               54959
# source                            2023
# export                               0
# deleted_rounds                   54908
# ...

# %%
jobma_pitcher_applied_jobs_df.describe().T
# Out:
#                        count                           mean  \
# jobma_applied_id     54961.0                   30550.644457
# jobma_pitcher_id     54961.0                   91597.584105
# jobma_post_id        54961.0                    8579.454995
# catcher_id           54345.0                     1811.22324
# jobma_assessment_id  34215.0                       2.656408
# invitation_id        54961.0                   43776.553793
# avg_ai_score            28.0                      63.921429
# deleted_at               268  2024-04-27 04:29:05.541044992
# created_at             54961  2019-05-26 01:10:57.697003520
# updated_at             54961  2021-12-11 18:58:42.767071744
#
#                                      min                         25%  \
# jobma_applied_id                   154.0                     14227.0
# jobma_pitcher_id                     0.0                     17874.0
# jobma_post_id                        0.0                       763.0
# ...

# %%
jobma_pitcher_applied_jobs_df.duplicated().sum()

# %%
jobma_pitcher_applied_jobs_df['catcher_id'].unique()

# %%
jobma_pitcher_applied_jobs_df['catcher_id'].head(5)

# %%
# Changing data type
jobma_pitcher_applied_jobs_df['catcher_id'] = jobma_pitcher_applied_jobs_df['catcher_id'].fillna(0).astype(int)

# %%
jobma_pitcher_applied_jobs_df['catcher_id'].head(10)

# %%
jobma_pitcher_applied_jobs_selected_df = jobma_pitcher_applied_jobs_df[['jobma_applied_id', #starts from 13
                                                                        # 'jobma_pitcher_id',#59540,59631,59775 likee
                                                                        # 'jobma_post_id',#0,763,759,770,771
                                                                        'catcher_id',#--------------------------------->> problem in catcher_id as in the workbench it is in but now in int as forcely changed
                                                                        # 'jobma_applied_date',#
                                                                        # 'jobma_contacted_date',#
                                                                        # 'jobma_contacted_text',#
                                                                        'status',#0,1,2,3,4---------->
                                                                        # 'tags',#test,arp,good,php,java
                                                                        # 'jobma_assessment_id',#float values  118.0,147.0,148.8.... mostly 0
                                                                        'invitation_id',#ids, mostly 0
                                                                        # 'documents',#mostly null or stringresums, summary
                                                                        #'status_name',#Null
                                                                        # 'pre_recorded_payment_status',#0,1 mostly 0
                                                                        # 'live_interview_payment_status',#0,1 mostly 0
                                                                        'apply_mode',#0,1,2,3,4,5,6 mostly
                                                                        'jobma_interview_rounds',#0,1,2,3,4
                                                                        # 'avg_ai_score',#Score generated by the AI found in only 15 tables
                                                                        # 'pre_screen_qualify',#0,1,2
                                                                        # 'integration_source',#one value in one colum
                                                                        # 'source',#jobma,microsoft teams,ZOom mostly jobma
                                                                        # 'export',#0,1 almost all are 0
                                                                        # 'deleted_rounds',####Problem  may be ticket raise
                                                                        # 'deleted_at',#
                                                                        # 'created_at',#
                                                                        # 'updated_at'
                                                                       ]].copy()

# %%
jobma_pitcher_applied_jobs_selected_df.info()

# %%
jobma_pitcher_applied_jobs_selected_df

# %%
jobma_pitcher_applied_jobs_selected_df.nunique()

# %%
jobma_pitcher_applied_jobs_selected_df.duplicated().sum()

# %%
jobma_pitcher_applied_jobs_selected_df['pitchers_counts'] = jobma_pitcher_applied_jobs_selected_df['catcher_id'].map(jobma_pitcher_applied_jobs_selected_df['catcher_id'].value_counts())

# %%
jobma_pitcher_applied_jobs_selected_df

# %%
jobma_pitcher_applied_jobs_selected_df.nunique()

# %%
jobma_pitcher_applied_jobs_selected_df.isna().sum()

# %%
jobma_pitcher_applied_jobs_selected_df=jobma_pitcher_applied_jobs_selected_df[['catcher_id','pitchers_counts', 'apply_mode']]

# %%
jobma_pitcher_applied_jobs_selected_df

# %%
jobma_pitcher_applied_jobs_selected_df

# %%
jobma_pitcher_applied_jobs_selected_df.duplicated().sum()

# %%
jobma_pitcher_applied_jobs_selected_df.drop_duplicates(inplace=True)

# %%
jobma_pitcher_applied_jobs_selected_df.shape

# %%
jobma_pitcher_applied_jobs_selected_df.isna().sum()

# %%
jobma_pitcher_applied_jobs_selected_df

# %%
jobma_pitcher_applied_jobs_selected_df.to_csv("pitchers_df.csv", index=False)
