# %%
import pandas as pd

# %%
catcher_df=pd.read_csv("catcher_df.csv")
login_df=pd.read_csv("login_df.csv")
wallet_df=pd.read_csv("clean_wallet_df.csv")
subscription_df=pd.read_csv("subscription_df1.csv")

#both Pre and Ai kits
kits_df=pd.read_csv("kits_pre_ai_outer_df.csv")

job_posting_df=pd.read_csv("job_posting_df.csv")
invitation_df=pd.read_csv("invitation_df.csv")
pitchers_df=pd.read_csv("pitchers_df.csv") #Number of pitcher client introduce to us

#intervies done
# interviews_df=pd.read_csv("interviews_df.csv")
# interviews_online_df=pd.read_csv("interviews_online_df.csv") #Interview given by candididate
# ai_interviews_df=pd.read_csv("ai_interviews_df.csv")
interviews_def_online_ai_df=pd.read_csv("interviews_def_online_ai_df.csv")

# %%
# catcher_df

# %%
catcher_df.shape, login_df.shape, wallet_df.shape, subscription_df.shape,
# Out:
# ((7672, 22), (7658, 3), (5562, 10), (7935, 5))

# %%
kits_df.shape, job_posting_df.shape, invitation_df.shape, pitchers_df.shape
# Out:
# ((1083, 2), (1292, 2), (1018, 2), (1154, 3))

# %%
# interviews_online_df.shape, ai_interviews_df.shape, interviews_df.shape
interviews_def_online_ai_df.shape
# Out:
# (879, 4)

# %%
job_posting_df
# Out:
#       catcher_id  position_created
# 0             92               825
# 1             97                 3
# 2             99               163
# 3             96                40
# 4            124                 1
# ...          ...               ...
# 1287        6543                 1
# 1288        9319               400
# 1289        9415                 1
# 1290        9433                 1
# 1291        9443                 1
#
# [1292 rows x 2 columns]

# %%
# catcher_df.T

# %%
# login_df.T

# %%
catcher_df.isna().sum()
# Out:
# catcher_id                    0
# jobma_catcher_company         1
# jobma_functional              0
# jobma_catcher_indus           0
# jobma_catcher_title           0
# jobma_catcher_otype           0
# jobma_catcher_status          0
# jobma_catcher_creation      182
# jobma_catcher_type            0
# is_premium                    0
# jobma_verified                0
# subscription_status           0
# sub_user                      0
# per_sub_user                  0
# live_interview_credit         0
# pre_recorded_credit           0
# ai_live_interview_credit      0
# interview_cost_type           0
# referral_credit               0
# company_size                  0
# ai_live_interview             0
# days_since_creation           0
# dtype: int64

# %%
catcher_login = pd.merge(catcher_df, login_df, 
                         on='catcher_id', 
                         how='inner')

catcher_login.shape
# Out:
# (7658, 24)

# %%
# catcher_login.isna().sum()

# %%
catcher_login_wallet = pd.merge(catcher_login, wallet_df, 
                                on='catcher_id', 
                                how='inner')

catcher_login_wallet.shape
# Out:
# (5549, 33)

# %%
# catcher_login_wallet.isna().sum()

# %%
catcher_login_wallet_sub = pd.merge(catcher_login_wallet, subscription_df, 
                                    on='catcher_id', 
                                    how='inner')

catcher_login_wallet_sub.shape
# Out:
# (7929, 37)

# %%
catcher_login_wallet_sub.duplicated().sum()
# Out:
# np.int64(0)

# %%
# catcher_login_wallet_sub.isna().sum()

# %%
catcher_login_wallet_sub_kits = pd.merge(catcher_login_wallet_sub, kits_df,
                                    on='catcher_id', 
                                    how='left')

catcher_login_wallet_sub_kits.shape
# Out:
# (7929, 38)

# %%
catcher_login_wallet_sub_kits.duplicated().sum()
# Out:
# np.int64(0)

# %%
# catcher_login_wallet_sub_kits.isna().sum()

# %%
catcher_login_wallet_sub_kits_jobposting = pd.merge(catcher_login_wallet_sub_kits, job_posting_df,
                                                    on='catcher_id', 
                                                    how='left')

catcher_login_wallet_sub_kits_jobposting.shape
# Out:
# (7929, 39)

# %%
catcher_login_wallet_sub_kits_jobposting_invite = pd.merge(catcher_login_wallet_sub_kits_jobposting, invitation_df, 
                                                           on='catcher_id', 
                                                           how='left')

catcher_login_wallet_sub_kits_jobposting_invite.shape
# Out:
# (7929, 40)

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher = pd.merge(catcher_login_wallet_sub_kits_jobposting_invite, pitchers_df, 
                                                                   on='catcher_id',
                                                                   how='left')

catcher_login_wallet_sub_kits_jobposting_invite_pitcher.shape
# Out:
# (8370, 42)

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df = pd.merge(catcher_login_wallet_sub_kits_jobposting_invite_pitcher, interviews_def_online_ai_df, 
                                                                                 on='catcher_id',
                                                                                 how='left')

catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.shape
# Out:
# (8370, 45)

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8370 entries, 0 to 8369
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   catcher_id                8370 non-null   int64
#  1   jobma_catcher_company     8369 non-null   object
#  2   jobma_functional          8370 non-null   object
#  3   jobma_catcher_indus       8370 non-null   object
#  4   jobma_catcher_title       8370 non-null   int64
#  5   jobma_catcher_otype       8370 non-null   object
#  6   jobma_catcher_status      8370 non-null   int64
#  7   jobma_catcher_creation    8158 non-null   object
#  8   jobma_catcher_type        8370 non-null   int64
#  9   is_premium                8370 non-null   int64
#  10  jobma_verified            8370 non-null   int64
#  11  subscription_status       8370 non-null   int64
#  12  sub_user                  8370 non-null   int64
#  13  per_sub_user              8370 non-null   object
#  14  live_interview_credit     8370 non-null   float64
#  15  pre_recorded_credit       8370 non-null   float64
#  16  ai_live_interview_credit  8370 non-null   float64
#  17  interview_cost_type       8370 non-null   int64
#  18  referral_credit           8370 non-null   int64
#  19  company_size              8370 non-null   object
#  20  ai_live_interview         8370 non-null   int64
#  21  days_since_creation       8370 non-null   float64
#  22  confirmed                 8370 non-null   int64
#  23  number_of_logins          8370 non-null   int64
#  24  id                        8370 non-null   int64
#  25  credit_amount             460 non-null    float64
#  26  wallet_amount             8370 non-null   float64
#  27  subscription_type         8370 non-null   int64
#  28  plan_type                 8362 non-null   float64
#  29  is_unlimited              8268 non-null   float64
#  30  premium_storage           8370 non-null   int64
#  31  trial_account_type        7958 non-null   float64
#  32  billing_cycle_status      8370 non-null   int64
#  33  subscription_amount       8370 non-null   float64
#  34  credit_given              8370 non-null   int64
#  35  currency_val              8370 non-null   float64
#  36  times_of_subscription     8370 non-null   int64
#  37  kits_count                1954 non-null   float64
#  38  position_created          1926 non-null   float64
#  39  number_of_invitations     1676 non-null   float64
#  40  pitchers_counts           1539 non-null   float64
#  41  apply_mode                1531 non-null   float64
#  42  def_interview_counts      1499 non-null   float64
#  43  interview_counts          1499 non-null   float64
#  44  ai_interview_counts       1499 non-null   float64
# dtypes: float64(19), int64(19), object(7)
# memory usage: 2.9+ MB

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.isna().sum().sort_values(ascending=False).head(35)
# Out:
# credit_amount             7910
# ai_interview_counts       6871
# def_interview_counts      6871
# interview_counts          6871
# apply_mode                6839
# pitchers_counts           6831
# number_of_invitations     6694
# position_created          6444
# kits_count                6416
# trial_account_type         412
# jobma_catcher_creation     212
# is_unlimited               102
# plan_type                    8
# jobma_catcher_company        1
# sub_user                     0
# jobma_verified               0
# subscription_status          0
# jobma_catcher_type           0
# jobma_catcher_status         0
# jobma_catcher_otype          0
# jobma_catcher_title          0
# jobma_functional             0
# jobma_catcher_indus          0
# catcher_id                   0
# is_premium                   0
# interview_cost_type          0
# referral_credit              0
# per_sub_user                 0
# live_interview_credit        0
# subscription_type            0
# wallet_amount                0
# number_of_logins             0
# id                           0
# confirmed                    0
# days_since_creation          0
# dtype: int64

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.shape
# Out:
# (8370, 45)

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.nunique()
# Out:
# catcher_id                  5529
# jobma_catcher_company       1860
# jobma_functional              95
# jobma_catcher_indus          340
# jobma_catcher_title            9
# jobma_catcher_otype            7
# jobma_catcher_status           3
# jobma_catcher_creation      1077
# jobma_catcher_type             2
# is_premium                     2
# jobma_verified                 2
# subscription_status            3
# sub_user                      62
# per_sub_user                   9
# live_interview_credit         22
# pre_recorded_credit           29
# ai_live_interview_credit       2
# interview_cost_type            2
# referral_credit                6
# company_size                   5
# ai_live_interview              2
# days_since_creation         1078
# confirmed                      2
# number_of_logins               6
# id                          5531
# credit_amount                 39
# wallet_amount                714
# subscription_type              2
# plan_type                      2
# is_unlimited                   2
# premium_storage                1
# trial_account_type             2
# billing_cycle_status           2
# subscription_amount          344
# credit_given                  37
# currency_val                  39
# times_of_subscription         37
# kits_count                    55
# position_created              62
# number_of_invitations        126
# pitchers_counts               89
# apply_mode                     5
# def_interview_counts          94
# interview_counts              27
# ai_interview_counts            4
# dtype: int64

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.to_csv("new_database.csv", index=False)
