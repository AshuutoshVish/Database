# %%
import pandas as pd

# %%
catcher_df=pd.read_csv("final_catcher_df.csv")
login_df=pd.read_csv("final_login_df.csv")

# wallet_df=pd.read_csv("final_wallet_df.csv")
wallet_df=pd.read_csv("new_final_wallet_df.csv")
subscription_df=pd.read_csv("final_subscrption_df.csv")

#both Pre_recorded and Ai kits
ai_video_kits_df=pd.read_csv("ai_video_kits_df.csv")
pre_recorded_kits_df=pd.read_csv("pre_recorded_kits_df.csv")

job_posting_df=pd.read_csv("job_posting_df.csv")#
invitation_df=pd.read_csv("job_invitations_df.csv")
pitchers_df=pd.read_csv("pitchers_applied_df.csv") #Number of pitcher client introduce to us

# intervies done #Interview given by candididate
pre_rec_interviews_df=pd.read_csv("pre_rec_interviews_df.csv")
live_interviews_df=pd.read_csv("live_interviews_df.csv") 
ai_interviews_df=pd.read_csv("ai_interviews_df.csv")

# %%
catcher_df.shape, login_df.shape, wallet_df.shape, subscription_df.shape,
# Out:
# ((5546, 12), (5546, 3), (5560, 5), (5560, 4))

# %%
ai_video_kits_df.shape, pre_recorded_kits_df.shape
# Out:
# ((9, 2), (1082, 2))

# %%
job_posting_df.shape, invitation_df.shape, pitchers_df.shape
# Out:
# ((1292, 2), (1018, 2), (956, 2))

# %%
pre_rec_interviews_df.shape, live_interviews_df.shape, ai_interviews_df.shape
# Out:
# ((865, 2), (121, 2), (3, 2))

# %%
# login_df.T

# %%
catcher_login = pd.merge(catcher_df, login_df, 
                         on='catcher_id', 
                         how='left')

catcher_login.shape
# Out:
# (5546, 14)

# %%
catcher_login.nunique()
# Out:
# catcher_id              5546
# jobma_catcher_status       2
# jobma_catcher_type         2
# is_premium                 2
# subscription_status        3
# sub_user                  48
# per_sub_user               9
# subscription_type          2
# referral_credit            2
# company_size               5
# ai_live_interview          2
# days_since_creation     1139
# number_of_logins           7
# days_since_login        1002
# dtype: int64

# %%
catcher_login.isna().sum()
# Out:
# catcher_id              0
# jobma_catcher_status    0
# jobma_catcher_type      0
# is_premium              1
# subscription_status     0
# sub_user                0
# per_sub_user            0
# subscription_type       0
# referral_credit         0
# company_size            0
# ai_live_interview       0
# days_since_creation     0
# number_of_logins        0
# days_since_login        0
# dtype: int64

# %%
catcher_login_wallet = pd.merge(catcher_login, wallet_df,
                                on='catcher_id', 
                                how='left')

catcher_login_wallet.shape
# Out:
# (5546, 18)

# %%
# catcher_login_wallet.isna().sum()

# %%
catcher_login_wallet_sub = pd.merge(catcher_login_wallet, subscription_df, 
                                    on='catcher_id', 
                                    how='left')

catcher_login_wallet_sub.shape
# Out:
# (5546, 21)

# %%
catcher_login_wallet_sub.duplicated().sum()
# Out:
# np.int64(0)

# %%
# catcher_login_wallet_sub.isna().sum()

# %%
catcher_login_wallet_sub_ai = pd.merge(catcher_login_wallet_sub, ai_video_kits_df,
                                    on='catcher_id', 
                                    how='left')

catcher_login_wallet_sub_ai.shape
# Out:
# (5546, 22)

# %%
catcher_login_wallet_sub_ai_pre = pd.merge(catcher_login_wallet_sub, pre_recorded_kits_df,
                                    on='catcher_id', 
                                    how='left')

catcher_login_wallet_sub_ai_pre.shape
# Out:
# (5546, 22)

# %%
catcher_login_wallet_sub_ai_pre.duplicated().sum()
# Out:
# np.int64(0)

# %%
# catcher_login_wallet_sub_kits.isna().sum()

# %%
catcher_login_wallet_sub_ai_pre_jobposting = pd.merge(catcher_login_wallet_sub_ai_pre, job_posting_df,
                                                    on='catcher_id', 
                                                    how='left')

catcher_login_wallet_sub_ai_pre_jobposting.shape
# Out:
# (5546, 23)

# %%
catcher_login_wallet_sub_ai_pre_jobposting_invite = pd.merge(catcher_login_wallet_sub_ai_pre_jobposting, invitation_df, 
                                                           on='catcher_id', 
                                                           how='left')

catcher_login_wallet_sub_ai_pre_jobposting_invite.shape
# Out:
# (5546, 24)

# %%
catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher = pd.merge(catcher_login_wallet_sub_ai_pre_jobposting_invite, pitchers_df, 
                                                                   on='catcher_id',
                                                                   how='left')

catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher.shape
# Out:
# (5546, 25)

# %%
catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher_prerec_df = pd.merge(catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher, pre_rec_interviews_df, 
                                                                                 on='catcher_id',
                                                                                 how='left')

catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher_prerec_df.shape
# Out:
# (5546, 26)

# %%
catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher_interviews__prerec_live_df = pd.merge(catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher, live_interviews_df, 
                                                                                 on='catcher_id',
                                                                                 how='left')

catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher_interviews__prerec_live_df.shape
# Out:
# (5546, 26)

# %%
catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher_interviews__prerec_live_ai_df = pd.merge(catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher, ai_interviews_df, 
                                                                                 on='catcher_id',
                                                                                 how='left')

catcher_login_wallet_sub_ai_pre_jobposting_invite_pitcher_interviews__prerec_live_ai_df.shape
# Out:
# (5546, 26)

# %%
# catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.info()

# %%
# catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.isna().sum().sort_values(ascending=False).head(35)

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.duplicated().sum()
#
# NameError: name 'catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df' is not defined

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.shape

# %%
# catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.nunique()

# %%
catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.duplicated().sum()

# %%
# catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.nunique()

# %%
# catcher_login_wallet_sub_kits_jobposting_invite_pitcher_interviews_df.to_csv("new_database.csv", index=False)
