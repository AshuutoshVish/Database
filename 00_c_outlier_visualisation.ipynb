# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("development.csv")
df.shape
# Out:
# (5546, 28)

# %%
df.columns
# Out:
# Index(['catcher_id', 'jobma_catcher_status', 'jobma_catcher_type',
#        'subscription_status', 'subscription_type', 'referral_credit',
#        'is_premium', 'sub_user', 'company_size', 'per_sub_user',
#        'number_of_logins', 'jobma_login_status', 'days_since_login',
#        'wallet_sum', 'plan_type', 'is_unlimited', 'subscription_sum',
#        'subscription_count', 'currency', 'premium_plan_id',
#        'pre_recorded_kit_counts', 'number_of_jobs_posted',
#        'number_of_invitations', 'number_of_pitcher_applied',
#        'pre_rec_interviews_counts', 'live_interviews_counts', 'ai_kit_counts',
#        'ai_interviews_counts'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5546 entries, 0 to 5545
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   catcher_id                 5546 non-null   int64
#  1   jobma_catcher_status       5546 non-null   int64
#  2   jobma_catcher_type         5546 non-null   int64
#  3   subscription_status        5546 non-null   int64
#  4   subscription_type          5546 non-null   int64
#  5   referral_credit            5546 non-null   int64
#  6   is_premium                 5546 non-null   int64
#  7   sub_user                   5546 non-null   int64
#  8   company_size               5546 non-null   object
#  9   per_sub_user               5546 non-null   float64
#  10  number_of_logins           5546 non-null   float64
#  11  jobma_login_status         5546 non-null   float64
#  12  days_since_login           5546 non-null   float64
#  13  wallet_sum                 5546 non-null   float64
#  14  plan_type                  5546 non-null   float64
#  15  is_unlimited               5546 non-null   float64
#  16  subscription_sum           5546 non-null   float64
#  17  subscription_count         5546 non-null   float64
#  18  currency                   5546 non-null   int64
#  19  premium_plan_id            5546 non-null   float64
#  20  pre_recorded_kit_counts    5546 non-null   float64
#  21  number_of_jobs_posted      5546 non-null   float64
#  22  number_of_invitations      5546 non-null   float64
#  23  number_of_pitcher_applied  5546 non-null   float64
#  24  pre_rec_interviews_counts  5546 non-null   float64
#  25  live_interviews_counts     5546 non-null   float64
#  26  ai_kit_counts              5546 non-null   float64
#  27  ai_interviews_counts       5546 non-null   float64
# dtypes: float64(18), int64(9), object(1)
# memory usage: 1.2+ MB

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
df.describe().T
# Out:
#                             count      mean        std   min     25%     50%  \
# catcher_id                5546.00   4766.99    2432.98 92.00 2772.25 4791.50
# jobma_catcher_status      5546.00      0.91       0.28  0.00    1.00    1.00
# jobma_catcher_type        5546.00      0.89       0.31  0.00    1.00    1.00
# subscription_status       5546.00      1.89       0.31  1.00    2.00    2.00
# subscription_type         5546.00      0.00       0.03  0.00    0.00    0.00
# referral_credit           5546.00      0.00       0.04  0.00    0.00    0.00
# is_premium                5546.00      0.38       0.49  0.00    0.00    0.00
# sub_user                  5546.00    255.07     427.84  0.00    1.00    5.00
# per_sub_user              5546.00   2258.58    4165.96  0.00  100.00  100.00
# number_of_logins          5546.00      1.02       0.24  0.00    1.00    1.00
# jobma_login_status        5546.00      0.04       0.19  0.00    0.00    0.00
# days_since_login          5546.00   1460.51     529.22  0.00 1070.00 1446.00
# wallet_sum                5546.00 162063.43 3004066.09  0.00   50.00  150.00
# plan_type                 5546.00      0.43       0.50  0.00    0.00    0.00
# is_unlimited              5546.00      0.14       0.35  0.00    0.00    0.00
# subscription_sum          5546.00 106834.01 2672119.66  0.00   53.10  300.00
# subscription_count        5546.00      1.98       4.59  0.00    1.00    1.00
# currency                  5546.00      0.44       0.50  0.00    0.00    0.00
# premium_plan_id           5546.00      3.48       1.30  0.00    3.00    3.00
# pre_recorded_kit_counts   5546.00      0.90       8.06  0.00    0.00    0.00
# number_of_jobs_posted     5546.00      1.51      18.59  0.00    0.00    0.00
# number_of_invitations     5546.00      8.71     102.41  0.00    0.00    0.00
# number_of_pitcher_applied 5546.00      6.56     239.93  0.00    0.00    0.00
# pre_rec_interviews_counts 5546.00      3.35      37.01  0.00    0.00    0.00
# live_interviews_counts    5546.00      0.17       3.27  0.00    0.00    0.00
# ai_kit_counts             5546.00      0.01       0.45  0.00    0.00    0.00
# ai_interviews_counts      5546.00      0.01       0.90  0.00    0.00    0.00
#
#                                75%          max
# catcher_id                 6914.75      9445.00
# jobma_catcher_status          1.00         1.00
# jobma_catcher_type            1.00         1.00
# subscription_status           2.00         2.00
# subscription_type             0.00         1.00
# referral_credit               0.00         1.00
# is_premium                    1.00         1.00
# sub_user                    108.50      1000.00
# per_sub_user                100.00     12000.00
# number_of_logins              1.00         5.00
# jobma_login_status            0.00         1.00
# days_since_login           1757.00      3124.00
# wallet_sum                 1100.00  99999999.00
# plan_type                     1.00         1.00
# is_unlimited                  0.00         1.00
# subscription_sum          10000.00 118872599.99
# subscription_count            2.00       238.00
# currency                      1.00         1.00
# premium_plan_id               4.00        10.00
# pre_recorded_kit_counts       0.00       297.00
# number_of_jobs_posted         0.00       825.00
# number_of_invitations         0.00      3396.00
# number_of_pitcher_applied     0.00     17640.00
# pre_rec_interviews_counts     0.00      1069.00
# live_interviews_counts        0.00       150.00
# ai_kit_counts                 0.00        32.00
# ai_interviews_counts          0.00        67.00

# %%
def plot_side_by_side_histograms(df, col1, col2, bins=30, figsize=(10, 3)):
    plt.figure(figsize=figsize)
    plt.subplot(1, 2, 1)
    sns.histplot(df[col1], color='blue', kde=True, bins=bins)
    plt.title(f'{col1} Distribution')
    plt.xlabel(col1)
    
    plt.subplot(1, 2, 2)
    sns.histplot(df[col2], color='orange', kde=True, bins=bins)
    plt.title(f'{col2} Distribution')
    plt.xlabel(col2)
    plt.tight_layout()
    plt.show()

# %%
df = df.assign(**{f'log_{col}': np.log1p(df[col]) for col in ['sub_user',
                                                              'wallet_sum', 
                                                              'subscription_sum',
                                                              'subscription_count',
                                                              'pre_recorded_kit_counts',
                                                              'number_of_jobs_posted',
                                                              'number_of_invitations',
                                                              'number_of_invitations',
                                                              'number_of_pitcher_applied',
                                                              'pre_rec_interviews_counts', 
                                                              'live_interviews_counts']})

# %%
plot_side_by_side_histograms(df, 'sub_user', 'log_sub_user')

# %%
plot_side_by_side_histograms(df, 'wallet_sum', 'log_wallet_sum')

# %%
plot_side_by_side_histograms(df, 'subscription_sum', 'log_subscription_sum')

# %%
plot_side_by_side_histograms(df, 'subscription_count', 'subscription_count')

# %%
plot_side_by_side_histograms(df, 'pre_recorded_kit_counts', 'log_pre_recorded_kit_counts')

# %%
plot_side_by_side_histograms(df, 'number_of_jobs_posted', 'log_number_of_jobs_posted')

# %%
plot_side_by_side_histograms(df, 'number_of_invitations', 'log_number_of_invitations')

# %%
plot_side_by_side_histograms(df, 'number_of_pitcher_applied', 'log_number_of_pitcher_applied')

# %%
plot_side_by_side_histograms(df, 'pre_rec_interviews_counts', 'log_pre_rec_interviews_counts')
