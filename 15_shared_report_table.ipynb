# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Jobma009%40@localhost:3306/jobma")

# %%
#subscription history #Share with sub-account or with main account.
shared_report_df = pd.read_sql("SELECT * FROM shared_report", engine)

# %%
shared_report_df
# Out:
#       id  report_id    report_type  shared_by  shared_to is_new  \
# 0      1        NaN  inviteListing       1371       1631      0
# 1      2        NaN  inviteListing       1692       1712      0
# 2      3        NaN  inviteListing       1371       1374      1
# 3      4        NaN  inviteListing       1692       1718      1
# 4      5        NaN  inviteListing       1371       1374      1
# ..   ...        ...            ...        ...        ...    ...
# 584  959      123.0  inviteListing       6543       7776      1
# 585  961      113.0  inviteListing       1873       9265      1
# 586  967      113.0  inviteListing       1873       9065      1
# 587  969      137.0    integration       8464          1      1
# 588  971      143.0  inviteListing       1873       5218      1
#
#                                        file_name  deleted_by          message  \
# 0                       2019-04-12_07-52-37.xlsx         NaN
# ...

# %%
shared_report_selected_df=shared_report_df[['id',#@589, 
                                            'report_id',#@29,  Nan, 89.0,113.0,55.0,.....
                                            'report_type',#@5,  category, report type, invite_listing, interview count, jobposting, integration
                                            'shared_by',#@83    1873--151, 2334--68, 3678--50, 1372--26
                                            'shared_to',#@174   9369---33, 3679--28..
                                            'is_new',#@3,  1, 0 , -
                                            'file_name',#
                                            'deleted_by',#@3, null mostly
                                            'message',#190 test, test, ok, may be some kind of message
                                            'created_at',
                                            'updated_at'
                                           ]]
